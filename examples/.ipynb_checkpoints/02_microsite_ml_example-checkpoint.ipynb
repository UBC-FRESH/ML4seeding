# %% [markdown]
# # 1. Import the necessery libraries

# %%
# !sudo nvidia-smi
# Out:
# Fri Jan 16 20:22:16 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.05              Driver Version: 580.95.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Quadro RTX 4000                Off |   00000000:18:00.0 Off |                  N/A |
# | 30%   30C    P8              9W /  125W |       9MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Quadro RTX 4000                Off |   00000000:3B:00.0 Off |                  N/A |
# | 30%   37C    P8             16W /  125W |     228MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # use GPU 1 only

import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
print("Visible GPUs:", gpus)

for gpu in gpus:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
    except:
        pass
# Out:
# 2026-01-16 20:22:17.552583: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-16 20:22:18.732937: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-16 20:22:21.944096: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Visible GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [raw]
# # If you want to use the spesific GPU
# # import os
# # os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # use GPU 1 or GPU 0
#
# import tensorflow as tf
#
# # List GPUs available
# gpus = tf.config.list_physical_devices('GPU')
# print("GPUs:", gpus)
#
# # Check if GPUs are available
# if gpus:
#     print("GPU is available.")
# else:
#     print("GPU is not available.")
#
# # Set memory growth for each GPU
# for gpu in gpus:
#     tf.config.experimental.set_memory_growth(gpu, True)

# %%
import numpy as np
import os
import pandas as pd 
import imageio 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout 
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate
from tensorflow.keras import regularizers

# %% [markdown]
# # 2. Load and split the data

# %%
image_dir = "./data_set/images/"  
mask_dir  = "./data_set/masks/" 

image_filenames = sorted([
    f for f in os.listdir(image_dir)
    if not f.startswith(".") and f.lower().endswith(".jpg")
])

mask_filenames = sorted([
    f for f in os.listdir(mask_dir)
    if not f.startswith(".") and f.lower().endswith(".png")
])

# Check that images and masks match correctly
for img, msk in zip(image_filenames, mask_filenames):
    if img.split('.')[0] != msk.split('.')[0]:
        print("❌ Mismatch:", img, msk)

image_list = [os.path.join(image_dir, f) for f in image_filenames]
mask_list  = [os.path.join(mask_dir,  f) for f in mask_filenames]

# Make the train/validation split dynamic
train_image_list, validation_image_list, train_mask_list, validation_mask_list = \
train_test_split(image_list, mask_list, test_size=0.2, random_state=42)

print("Total images:", len(image_list))
print("image_list:", train_image_list)

print("Total masks:", len(mask_list))
print("mask_list:", train_mask_list)

unique_values = np.unique(imageio.v2.imread(mask_list[0]))
print("Mask classes:", unique_values)
# Out:
# Total images: 8
# image_list: ['./data_set/images/post-harvest_01.jpg', './data_set/images/post-harvest_03_3.jpg', './data_set/images/post-harvest_01_3.jpg', './data_set/images/post-harvest_02_2.jpg', './data_set/images/post-harvest_02.jpg', './data_set/images/post-harvest_03_2.jpg']
# Total masks: 8
# mask_list: ['./data_set/masks/post-harvest_01.png', './data_set/masks/post-harvest_03_3.png', './data_set/masks/post-harvest_01_3.png', './data_set/masks/post-harvest_02_2.png', './data_set/masks/post-harvest_02.png', './data_set/masks/post-harvest_03_2.png']
# Mask classes: [0 1 2 3]

# %% [markdown]
# # 3. explore some images :

# %%
def load_and_plot_image_mask(img_path, mask_path):
    """
    Loads an image and mask, keeps original size, prints shapes, and plots:
        1. Original image
        2. Original mask in color
        3. Overlay of mask on the image

    Args:
        img_path (str): Path to the image file
        mask_path (str): Path to the mask file

    Returns:
        img (tf.Tensor): Normalized image tensor (0-1)
        mask (tf.Tensor): Integer mask tensor
    """
    
    # Define colors for mask classes: background, good, fair, poor
    class_colors = np.array([
        [0, 0, 0],        # 0 = background (black)
        [0, 255, 0],      # 1 = good (green)
        [255, 255, 0],    # 2 = fair (yellow)
        [255, 0, 0]       # 3 = poor (red)
    ], dtype=np.uint8)
    
    # Load image
    img = imageio.imread(img_path)
    img = tf.cast(img, tf.float32) / 255.0  # normalize to 0-1
    
    # Load mask
    mask = imageio.imread(mask_path)
    mask = tf.cast(mask[..., np.newaxis], tf.uint8)[...,0].numpy()  # keep integers
    
    # Print shapes
    print("Image shape:", img.shape)
    print("Mask shape:", mask.shape)
    
    # Convert mask to color
    mask_color = class_colors[mask]
    
    # Plotting
    fig, ax = plt.subplots(1, 3, figsize=(20, 10))
    
    # Original image
    ax[0].imshow(img)
    ax[0].set_title("Original Image")
    ax[0].axis('on')
    
    # Original mask in color
    ax[1].imshow(mask_color)
    ax[1].set_title("Original Mask (Color)")
    ax[1].axis('on')
    
    # Overlay
    overlay = (0.6 * img.numpy() + 0.4 * mask_color / 255.0)
    ax[2].imshow(overlay)
    ax[2].set_title("Overlay")
    ax[2].axis('on')
    
    plt.show()
    
    # Print unique mask values for sanity check
    print("Unique mask values:", np.unique(mask))
    
    return img, mask

# %%
n = 1
img, mask = load_and_plot_image_mask(train_image_list[n], train_mask_list[n])
# Out:
# /tmp/ipykernel_10326/2670707206.py:26: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(img_path)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768594947.124388   10326 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6378 MB memory:  -> device: 0, name: Quadro RTX 4000, pci bus id: 0000:3b:00.0, compute capability: 7.5
# /tmp/ipykernel_10326/2670707206.py:30: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mask = imageio.imread(mask_path)
# Image shape: (312, 312, 3)
# Mask shape: (312, 312)
# Unique mask values: [0 1 2 3]

# %%
train_images = tf.constant(train_image_list)
train_masks = tf.constant(train_mask_list)

train_dataset = tf.data.Dataset.from_tensor_slices((train_images,train_masks))
for image,mask in train_dataset.take(1) : 
    print(image)
    print(mask)
    
validation_images = tf.constant(validation_image_list)
validation_masks = tf.constant(validation_mask_list)

validation_dataset = tf.data.Dataset.from_tensor_slices((validation_images,validation_masks))
for image,mask in validation_dataset.take(1) : 
    print(image)
    print(mask)
# Out:
# tf.Tensor(b'./data_set/images/post-harvest_01.jpg', shape=(), dtype=string)
# tf.Tensor(b'./data_set/masks/post-harvest_01.png', shape=(), dtype=string)
# tf.Tensor(b'./data_set/images/post-harvest_01_2.jpg', shape=(), dtype=string)
# tf.Tensor(b'./data_set/masks/post-harvest_01_2.png', shape=(), dtype=string)
# 2026-01-16 20:22:27.752553: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-01-16 20:22:27.777485: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # 4. preprocessing our data

# %%
def process_path(image_path,mask_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img,channels=3)
    img = tf.image.convert_image_dtype(img,tf.float32) #this do the same as dividing by 255 to set the values between 0 and 1 (normalization)    
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask,channels=3)
    mask = tf.math.reduce_max(mask,axis=-1,keepdims=True)
    return img , mask

def preprocess(image,mask) : 
    input_image = tf.image.resize(image,(96,128),method='nearest') # consider keeping higher resolution (e.g., 256×256) if GPU memory allows.
    input_mask = tf.image.resize(mask,(96,128),method='nearest')    
    return input_image , input_mask

train_image_ds = train_dataset.map(process_path) # apply the preprocces_path function to our train_dataset
print(train_image_ds)
train_processed_image_ds = train_image_ds.map(preprocess) # apply the preprocess function to our train_dataset

validation_image_ds = validation_dataset.map(process_path) # apply the preprocces_path function to our validation_dataset
print(validation_image_ds)
validation_processed_image_ds = validation_image_ds.map(preprocess)
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.uint8, name=None))>
# <_MapDataset element_spec=(TensorSpec(shape=(None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.uint8, name=None))>

# %%
# Add data augmentation (flips, rotations)
# def augment(image, mask):
#     if tf.random.uniform(()) > 0.5:
#         image = tf.image.flip_left_right(image)
#         mask = tf.image.flip_left_right(mask)
#     return image, mask
# train_processed_image_ds = train_processed_image_ds.map(augment)

# %% [markdown]
# # Defining mean iou metric

# %%
NUM_CLASSES = 4

def mean_iou_metric(y_true, y_pred, smooth=1e-7):
    # y_true: (B, H, W) or (B, H, W, 1)
    # y_pred: (B, H, W, NUM_CLASSES) logits
    
    # Squeeze extra channel if exists
    if y_true.shape.rank == 4 and y_true.shape[-1] == 1:
        y_true = tf.squeeze(y_true, axis=-1)
    
    y_true = tf.cast(y_true, tf.int32)

    # Convert logits → class probabilities
    y_pred = tf.nn.softmax(y_pred, axis=-1)

    # Get predicted class ID
    y_pred_labels = tf.argmax(y_pred, axis=-1, output_type=tf.int32)

    # Compute IoU per class
    ious = []
    for c in range(NUM_CLASSES):
        y_true_c = tf.cast(tf.equal(y_true, c), tf.float32)
        y_pred_c = tf.cast(tf.equal(y_pred_labels, c), tf.float32)

        intersection = tf.reduce_sum(y_true_c * y_pred_c)
        union = tf.reduce_sum(y_true_c) + tf.reduce_sum(y_pred_c) - intersection

        iou = (intersection + smooth) / (union + smooth)
        ious.append(iou)

    # Return mean IoU over classes
    return tf.reduce_mean(tf.stack(ious))

# %% [markdown]
# # 5.  Define The Conv Block For The Contracting Path

# %%
def conv_block(inputs=None, n_filters=32, dropout_prob=0, max_pooling=True):
    
    conv = Conv2D(n_filters, 
                  kernel_size = 3,     
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(inputs)
    conv = Conv2D(n_filters, 
                  kernel_size = 3, 
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(conv)
   
    

    if dropout_prob > 0:
        conv = Dropout(dropout_prob)(conv)
        
    if max_pooling:
        next_layer = MaxPooling2D(pool_size=(2,2))(conv)
        
        
    else:
        next_layer = conv
        
    skip_connection = conv
    
    return next_layer, skip_connection

# %% [markdown]
# # 6. Define the upsampling block for the expanding path

# %%
def upsampling_block(expansive_input, contractive_input, n_filters=32):
    
    up = Conv2DTranspose(
                 n_filters,  
                 kernel_size = 3,
                 strides=(2,2),
                 padding='same')(expansive_input)
    
    merge = concatenate([up, contractive_input], axis=3)
    conv = Conv2D(n_filters,  
                 kernel_size = 3,   
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(merge)
    conv = Conv2D(n_filters,  
                 kernel_size = 3,  
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(conv)
        
    return conv

# %% [markdown]
# # 7. Finally! ,  we will Define the unet model
# ## which composes of a set of conv blocks and upsampling blocks

# %%
def unet_model(input_size=(96, 128, 3), n_filters=32, n_classes=4):
    
    inputs = Input(input_size)
    
    # contracting path
    cblock1 = conv_block(inputs, n_filters, dropout_prob=0.4)
    cblock2 = conv_block(cblock1[0], 2*n_filters, dropout_prob=0.4)
    cblock3 = conv_block(cblock2[0], 4*n_filters, dropout_prob=0.4)
    cblock4 = conv_block(cblock3[0], 8*n_filters, dropout_prob=0.45) 
    cblock5 = conv_block(cblock4[0],16*n_filters, dropout_prob=0.4, max_pooling=None)     
    
    # expanding path
    ublock6 = upsampling_block(cblock5[0], cblock4[1],  8 * n_filters)
    ublock7 = upsampling_block(ublock6, cblock3[1],  n_filters*4)
    ublock8 = upsampling_block(ublock7,cblock2[1] , n_filters*2)
    ublock9 = upsampling_block(ublock8,cblock1[1],  n_filters)

    conv9 = Conv2D(n_filters,
                 3,
                 activation='relu',
                 padding='same',
                 kernel_initializer='he_normal')(ublock9)
    
    conv10 = Conv2D(n_classes, kernel_size=1, activation='softmax', padding='same')(conv9)
    # conv10 = Conv2D(n_classes, kernel_size=1, padding='same')(conv9)  

    model = tf.keras.Model(inputs=inputs, outputs=conv10)

    return model

# %%
img_height = 96
img_width = 128
num_channels = 3

unet = unet_model((img_height, img_width, num_channels))

# %% [markdown]
# # 8. Our model is ready !!

# %%
unet.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 96, 128,   │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 96, 128,   │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 96, 128,   │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 96, 128,   │          0 │ conv2d_1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 48, 64,    │          0 │ dropout[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 48, 64,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 48, 64,    │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 48, 64,    │          0 │ conv2d_3[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 24, 32,    │          0 │ dropout_1[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 24, 32,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 24, 32,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 24, 32,    │          0 │ conv2d_5[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 12, 16,    │          0 │ dropout_2[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 12, 16,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 12, 16,    │    590,080 │ conv2d_6[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 12, 16,    │          0 │ conv2d_7[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 6, 8, 256) │          0 │ dropout_3[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 6, 8, 512) │  1,180,160 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 6, 8, 512) │  2,359,808 │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 6, 8, 512) │          0 │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 12, 16,    │  1,179,904 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 12, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 12, 16,    │  1,179,904 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 12, 16,    │    590,080 │ conv2d_10[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 24, 32,    │    295,040 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 24, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 24, 32,    │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 24, 32,    │    147,584 │ conv2d_12[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 48, 64,    │     73,792 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 48, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 48, 64,    │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 48, 64,    │     36,928 │ conv2d_14[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 96, 128,   │     18,464 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 96, 128,   │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 96, 128,   │     18,464 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 96, 128,   │      9,248 │ conv2d_16[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 96, 128,   │      9,248 │ conv2d_17[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 96, 128,   │        132 │ conv2d_18[0][0]   │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,639,844 (32.96 MB)
#  Trainable params: 8,639,844 (32.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
unet.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy', mean_iou_metric])

# %%
EPOCHS = 500
BUFFER_SIZE = 390
BATCH_SIZE = 1

# train
# train_processed_image_ds.batch(BATCH_SIZE)
train_dataset = train_processed_image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
print(train_processed_image_ds.element_spec)

# validation
# validation_processed_image_ds.batch(BATCH_SIZE)
# validation_dataset = validation_processed_image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
validation_dataset = validation_processed_image_ds.cache().batch(BATCH_SIZE)

print(validation_processed_image_ds.element_spec)
 

model_history = unet.fit(train_dataset, epochs=EPOCHS)
# Out:
# (TensorSpec(shape=(96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(96, 128, 1), dtype=tf.uint8, name=None))
# (TensorSpec(shape=(96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(96, 128, 1), dtype=tf.uint8, name=None))
# Epoch 1/500
# /home/eghase02/venvs/tf220/lib/python3.12/site-packages/keras/src/backend/tensorflow/nn.py:717: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 2026-01-16 20:22:33.867776: I external/local_xla/xla/service/service.cc:163] XLA service 0x76ca18002540 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-01-16 20:22:33.867805: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): Quadro RTX 4000, Compute Capability 7.5
# 2026-01-16 20:22:34.078429: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-01-16 20:22:34.472922: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2026-01-16 20:22:34.981386: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91500
# 2026-01-16 20:22:36.397972: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,64,24,32]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:22:36.453531: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,128,24,32]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:22:36.509394: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,128,12,16]{3,2,1,0}, f32[256,128,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:22:36.567449: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,256,12,16]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:22:36.626272: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,512,6,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,256,6,8]{3,2,1,0}, f32[512,256,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:22:36.707755: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,512,6,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,512,6,8]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:22:37.057584: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,512,12,16]{3,2,1,0}, f32[256,512,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:22:37.188972: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,256,24,32]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - accuracy: 0.3427 - loss: 1.4111 - mean_iou_metric: 0.1275
# Epoch 2/500
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4395 - loss: 1.2873 - mean_iou_metric: 0.1876
# I0000 00:00:1768594964.272391   10621 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4024 - loss: 1.2776 - mean_iou_metric: 0.1580
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4083 - loss: 1.2115 - mean_iou_metric: 0.1391
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5189 - loss: 1.1356 - mean_iou_metric: 0.2278
# Epoch 5/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5485 - loss: 1.0854 - mean_iou_metric: 0.2404
# Epoch 6/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5816 - loss: 1.0076 - mean_iou_metric: 0.2704
# Epoch 7/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5996 - loss: 0.9652 - mean_iou_metric: 0.2850
# Epoch 8/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5837 - loss: 0.9784 - mean_iou_metric: 0.2786
# Epoch 9/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5556 - loss: 0.9985 - mean_iou_metric: 0.2521
# Epoch 10/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6091 - loss: 0.9157 - mean_iou_metric: 0.3114
# Epoch 11/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6184 - loss: 0.8567 - mean_iou_metric: 0.3061
# Epoch 12/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6259 - loss: 0.8385 - mean_iou_metric: 0.3098
# Epoch 13/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6516 - loss: 0.7549 - mean_iou_metric: 0.3476
# Epoch 14/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6332 - loss: 0.7883 - mean_iou_metric: 0.3375
# Epoch 15/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6491 - loss: 0.7788 - mean_iou_metric: 0.3513
# Epoch 16/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6233 - loss: 0.8089 - mean_iou_metric: 0.3181
# Epoch 17/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6418 - loss: 0.7798 - mean_iou_metric: 0.3330
# Epoch 18/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6410 - loss: 0.7722 - mean_iou_metric: 0.3329
# Epoch 19/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6431 - loss: 0.7551 - mean_iou_metric: 0.3308
# Epoch 20/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6547 - loss: 0.7265 - mean_iou_metric: 0.3391
# Epoch 21/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6419 - loss: 0.7609 - mean_iou_metric: 0.3445
# Epoch 22/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6441 - loss: 0.7259 - mean_iou_metric: 0.3497
# Epoch 23/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6605 - loss: 0.6939 - mean_iou_metric: 0.3609
# Epoch 24/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6606 - loss: 0.6789 - mean_iou_metric: 0.3613
# Epoch 25/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6417 - loss: 0.7155 - mean_iou_metric: 0.3472
# Epoch 26/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6617 - loss: 0.7196 - mean_iou_metric: 0.3839
# Epoch 27/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6636 - loss: 0.6832 - mean_iou_metric: 0.3572
# Epoch 28/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6378 - loss: 0.8113 - mean_iou_metric: 0.3581
# Epoch 29/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6385 - loss: 0.7964 - mean_iou_metric: 0.3603
# Epoch 30/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6483 - loss: 0.7845 - mean_iou_metric: 0.3424
# Epoch 31/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6679 - loss: 0.7399 - mean_iou_metric: 0.3613
# Epoch 32/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6190 - loss: 0.7719 - mean_iou_metric: 0.3241
# Epoch 33/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6617 - loss: 0.6888 - mean_iou_metric: 0.3646
# Epoch 34/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6541 - loss: 0.6673 - mean_iou_metric: 0.3657
# Epoch 35/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6716 - loss: 0.6415 - mean_iou_metric: 0.3881
# Epoch 36/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6993 - loss: 0.6341 - mean_iou_metric: 0.4274
# Epoch 37/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7392 - loss: 0.5962 - mean_iou_metric: 0.4638
# Epoch 38/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7579 - loss: 0.6068 - mean_iou_metric: 0.4837
# Epoch 39/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7507 - loss: 0.6240 - mean_iou_metric: 0.4856
# Epoch 40/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7099 - loss: 0.6473 - mean_iou_metric: 0.4565
# Epoch 41/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7260 - loss: 0.6425 - mean_iou_metric: 0.4580
# Epoch 42/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7558 - loss: 0.5690 - mean_iou_metric: 0.4820
# Epoch 43/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6890 - loss: 0.6640 - mean_iou_metric: 0.4499
# Epoch 44/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7617 - loss: 0.6356 - mean_iou_metric: 0.4997
# Epoch 45/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7338 - loss: 0.6351 - mean_iou_metric: 0.4520
# Epoch 46/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7963 - loss: 0.5576 - mean_iou_metric: 0.5330
# Epoch 47/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8003 - loss: 0.5660 - mean_iou_metric: 0.5435
# Epoch 48/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7631 - loss: 0.5583 - mean_iou_metric: 0.5237
# Epoch 49/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7836 - loss: 0.5482 - mean_iou_metric: 0.5345
# Epoch 50/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7329 - loss: 2.1372 - mean_iou_metric: 0.4664
# Epoch 51/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5094 - loss: 1.5524 - mean_iou_metric: 0.2760
# Epoch 52/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5768 - loss: 1.0529 - mean_iou_metric: 0.3178
# Epoch 53/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5355 - loss: 1.0527 - mean_iou_metric: 0.2546
# Epoch 54/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5692 - loss: 0.8815 - mean_iou_metric: 0.2876
# Epoch 55/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6311 - loss: 0.8227 - mean_iou_metric: 0.3118
# Epoch 56/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6394 - loss: 0.8092 - mean_iou_metric: 0.3186
# Epoch 57/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6416 - loss: 0.7892 - mean_iou_metric: 0.3237
# Epoch 58/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6385 - loss: 0.7688 - mean_iou_metric: 0.3348
# Epoch 59/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6269 - loss: 0.7730 - mean_iou_metric: 0.3398
# Epoch 60/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6396 - loss: 0.7620 - mean_iou_metric: 0.3466
# Epoch 61/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6381 - loss: 0.7745 - mean_iou_metric: 0.3315
# Epoch 62/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6494 - loss: 0.7678 - mean_iou_metric: 0.3481
# Epoch 63/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6407 - loss: 0.7673 - mean_iou_metric: 0.3364
# Epoch 64/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6503 - loss: 0.7330 - mean_iou_metric: 0.3496
# Epoch 65/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6537 - loss: 0.7306 - mean_iou_metric: 0.3523
# Epoch 66/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6547 - loss: 0.7263 - mean_iou_metric: 0.3583
# Epoch 67/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6555 - loss: 0.7178 - mean_iou_metric: 0.3545
# Epoch 68/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6436 - loss: 0.7603 - mean_iou_metric: 0.3472
# Epoch 69/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6363 - loss: 0.8107 - mean_iou_metric: 0.3532
# Epoch 70/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6409 - loss: 0.7806 - mean_iou_metric: 0.3521
# Epoch 71/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6486 - loss: 0.7650 - mean_iou_metric: 0.3672
# Epoch 72/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6646 - loss: 0.7209 - mean_iou_metric: 0.3752
# Epoch 73/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6523 - loss: 0.7191 - mean_iou_metric: 0.3585
# Epoch 74/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6579 - loss: 0.7080 - mean_iou_metric: 0.3620
# Epoch 75/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6587 - loss: 0.7138 - mean_iou_metric: 0.3708
# Epoch 76/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6583 - loss: 0.7065 - mean_iou_metric: 0.3681
# Epoch 77/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6694 - loss: 0.6889 - mean_iou_metric: 0.3866
# Epoch 78/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6565 - loss: 0.7185 - mean_iou_metric: 0.3749
# Epoch 79/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6627 - loss: 0.7212 - mean_iou_metric: 0.3933
# Epoch 80/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6578 - loss: 0.6971 - mean_iou_metric: 0.3981
# Epoch 81/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6736 - loss: 0.6846 - mean_iou_metric: 0.4065
# Epoch 82/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6652 - loss: 0.7082 - mean_iou_metric: 0.3892
# Epoch 83/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6886 - loss: 0.6758 - mean_iou_metric: 0.4275
# Epoch 84/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7123 - loss: 0.6719 - mean_iou_metric: 0.4400
# Epoch 85/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6824 - loss: 0.6665 - mean_iou_metric: 0.4214
# Epoch 86/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6848 - loss: 0.6963 - mean_iou_metric: 0.4338
# Epoch 87/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7139 - loss: 0.6596 - mean_iou_metric: 0.4608
# Epoch 88/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6857 - loss: 0.6840 - mean_iou_metric: 0.4107
# Epoch 89/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7058 - loss: 0.6758 - mean_iou_metric: 0.4388
# Epoch 90/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7426 - loss: 0.6421 - mean_iou_metric: 0.4717
# Epoch 91/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7611 - loss: 0.6336 - mean_iou_metric: 0.4838
# Epoch 92/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7325 - loss: 0.6502 - mean_iou_metric: 0.4705
# Epoch 93/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7539 - loss: 0.6356 - mean_iou_metric: 0.4793
# Epoch 94/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7714 - loss: 0.6203 - mean_iou_metric: 0.5041
# Epoch 95/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7385 - loss: 0.6259 - mean_iou_metric: 0.4603
# Epoch 96/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7731 - loss: 0.6082 - mean_iou_metric: 0.4969
# Epoch 97/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7814 - loss: 0.5924 - mean_iou_metric: 0.5098
# Epoch 98/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7799 - loss: 0.5719 - mean_iou_metric: 0.5090
# Epoch 99/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7836 - loss: 0.5749 - mean_iou_metric: 0.5108
# Epoch 100/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7338 - loss: 0.6365 - mean_iou_metric: 0.4618
# Epoch 101/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7466 - loss: 0.5991 - mean_iou_metric: 0.4791
# Epoch 102/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7841 - loss: 0.5688 - mean_iou_metric: 0.4983
# Epoch 103/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7768 - loss: 0.5719 - mean_iou_metric: 0.4983
# Epoch 104/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7890 - loss: 0.5392 - mean_iou_metric: 0.5167
# Epoch 105/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7994 - loss: 0.5243 - mean_iou_metric: 0.5230
# Epoch 106/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7732 - loss: 0.5711 - mean_iou_metric: 0.5012
# Epoch 107/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7799 - loss: 0.5565 - mean_iou_metric: 0.5113
# Epoch 108/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7955 - loss: 0.5216 - mean_iou_metric: 0.5131
# Epoch 109/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7618 - loss: 0.5702 - mean_iou_metric: 0.4872
# Epoch 110/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7740 - loss: 0.5593 - mean_iou_metric: 0.5101
# Epoch 111/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8016 - loss: 0.5161 - mean_iou_metric: 0.5281
# Epoch 112/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8010 - loss: 0.5054 - mean_iou_metric: 0.5353
# Epoch 113/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8114 - loss: 0.4790 - mean_iou_metric: 0.5426
# Epoch 114/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7984 - loss: 0.4994 - mean_iou_metric: 0.5411
# Epoch 115/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8228 - loss: 0.4794 - mean_iou_metric: 0.5683
# Epoch 116/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8011 - loss: 0.4890 - mean_iou_metric: 0.5382
# Epoch 117/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8018 - loss: 0.4887 - mean_iou_metric: 0.5384
# Epoch 118/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8132 - loss: 0.4786 - mean_iou_metric: 0.5498
# Epoch 119/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7936 - loss: 0.5106 - mean_iou_metric: 0.5214
# Epoch 120/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8177 - loss: 0.4641 - mean_iou_metric: 0.5602
# Epoch 121/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8212 - loss: 0.4449 - mean_iou_metric: 0.5563
# Epoch 122/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8343 - loss: 0.4224 - mean_iou_metric: 0.5852
# Epoch 123/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8392 - loss: 0.4188 - mean_iou_metric: 0.5898
# Epoch 124/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8454 - loss: 0.4007 - mean_iou_metric: 0.6008
# Epoch 125/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8306 - loss: 0.4212 - mean_iou_metric: 0.5843
# Epoch 126/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8321 - loss: 0.4223 - mean_iou_metric: 0.5868
# Epoch 127/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8252 - loss: 0.4389 - mean_iou_metric: 0.5747
# Epoch 128/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8081 - loss: 0.4690 - mean_iou_metric: 0.5663
# Epoch 129/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8000 - loss: 0.5052 - mean_iou_metric: 0.5545
# Epoch 130/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8182 - loss: 0.4811 - mean_iou_metric: 0.5723
# Epoch 131/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8183 - loss: 0.4744 - mean_iou_metric: 0.5630
# Epoch 132/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8074 - loss: 0.4802 - mean_iou_metric: 0.5377
# Epoch 133/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8432 - loss: 0.4216 - mean_iou_metric: 0.5991
# Epoch 134/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8463 - loss: 0.3987 - mean_iou_metric: 0.5951
# Epoch 135/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8321 - loss: 0.4563 - mean_iou_metric: 0.5824
# Epoch 136/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8416 - loss: 0.4032 - mean_iou_metric: 0.5847
# Epoch 137/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8520 - loss: 0.3858 - mean_iou_metric: 0.6238
# Epoch 138/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8602 - loss: 0.3820 - mean_iou_metric: 0.6365
# Epoch 139/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8598 - loss: 0.3710 - mean_iou_metric: 0.6277
# Epoch 140/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8577 - loss: 0.3721 - mean_iou_metric: 0.6211
# Epoch 141/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8601 - loss: 0.3714 - mean_iou_metric: 0.6298
# Epoch 142/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8155 - loss: 0.4771 - mean_iou_metric: 0.5817
# Epoch 143/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8410 - loss: 0.4107 - mean_iou_metric: 0.5906
# Epoch 144/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8536 - loss: 0.3771 - mean_iou_metric: 0.6192
# Epoch 145/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8642 - loss: 0.3558 - mean_iou_metric: 0.6287
# Epoch 146/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8613 - loss: 0.3616 - mean_iou_metric: 0.6297
# Epoch 147/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8536 - loss: 0.3919 - mean_iou_metric: 0.6268
# Epoch 148/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7873 - loss: 0.5565 - mean_iou_metric: 0.5477
# Epoch 149/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7941 - loss: 0.5473 - mean_iou_metric: 0.5483
# Epoch 150/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7516 - loss: 0.6303 - mean_iou_metric: 0.4990
# Epoch 151/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8020 - loss: 0.5125 - mean_iou_metric: 0.5244
# Epoch 152/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8329 - loss: 0.4608 - mean_iou_metric: 0.5795
# Epoch 153/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7888 - loss: 0.5120 - mean_iou_metric: 0.5295
# Epoch 154/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8401 - loss: 0.4012 - mean_iou_metric: 0.5775
# Epoch 155/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8489 - loss: 0.3951 - mean_iou_metric: 0.6098
# Epoch 156/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8641 - loss: 0.3660 - mean_iou_metric: 0.6333
# Epoch 157/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8725 - loss: 0.3420 - mean_iou_metric: 0.6433
# Epoch 158/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8728 - loss: 0.3364 - mean_iou_metric: 0.6455
# Epoch 159/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8741 - loss: 0.3385 - mean_iou_metric: 0.6568
# Epoch 160/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8841 - loss: 0.3099 - mean_iou_metric: 0.6716
# Epoch 161/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8893 - loss: 0.2972 - mean_iou_metric: 0.6782
# Epoch 162/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8893 - loss: 0.2910 - mean_iou_metric: 0.6803
# Epoch 163/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8963 - loss: 0.2798 - mean_iou_metric: 0.6906
# Epoch 164/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8930 - loss: 0.2837 - mean_iou_metric: 0.6862
# Epoch 165/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8896 - loss: 0.2911 - mean_iou_metric: 0.6821
# Epoch 166/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8870 - loss: 0.2944 - mean_iou_metric: 0.6732
# Epoch 167/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8904 - loss: 0.2897 - mean_iou_metric: 0.6885
# Epoch 168/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8959 - loss: 0.2812 - mean_iou_metric: 0.6930
# Epoch 169/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9003 - loss: 0.2681 - mean_iou_metric: 0.7010
# Epoch 170/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9021 - loss: 0.2644 - mean_iou_metric: 0.7105
# Epoch 171/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9017 - loss: 0.2598 - mean_iou_metric: 0.7103
# Epoch 172/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9029 - loss: 0.2580 - mean_iou_metric: 0.7078
# Epoch 173/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9016 - loss: 0.2639 - mean_iou_metric: 0.7086
# Epoch 174/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9035 - loss: 0.2566 - mean_iou_metric: 0.7147
# Epoch 175/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9006 - loss: 0.2796 - mean_iou_metric: 0.7080
# Epoch 176/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9013 - loss: 0.2602 - mean_iou_metric: 0.7096
# Epoch 177/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9080 - loss: 0.2469 - mean_iou_metric: 0.7210
# Epoch 178/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9091 - loss: 0.2451 - mean_iou_metric: 0.7243
# Epoch 179/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9063 - loss: 0.2523 - mean_iou_metric: 0.7268
# Epoch 180/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9090 - loss: 0.2461 - mean_iou_metric: 0.7229
# Epoch 181/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9041 - loss: 0.2504 - mean_iou_metric: 0.7168
# Epoch 182/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9049 - loss: 0.2474 - mean_iou_metric: 0.7205
# Epoch 183/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9104 - loss: 0.2373 - mean_iou_metric: 0.7271
# Epoch 184/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9125 - loss: 0.2367 - mean_iou_metric: 0.7344
# Epoch 185/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9119 - loss: 0.2324 - mean_iou_metric: 0.7278
# Epoch 186/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9144 - loss: 0.2268 - mean_iou_metric: 0.7426
# Epoch 187/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9181 - loss: 0.2191 - mean_iou_metric: 0.7532
# Epoch 188/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9167 - loss: 0.2223 - mean_iou_metric: 0.7441
# Epoch 189/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9151 - loss: 0.2234 - mean_iou_metric: 0.7368
# Epoch 190/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9175 - loss: 0.2185 - mean_iou_metric: 0.7440
# Epoch 191/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9157 - loss: 0.2265 - mean_iou_metric: 0.7461
# Epoch 192/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9162 - loss: 0.2283 - mean_iou_metric: 0.7463
# Epoch 193/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9154 - loss: 0.2261 - mean_iou_metric: 0.7421
# Epoch 194/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9182 - loss: 0.2180 - mean_iou_metric: 0.7507
# Epoch 195/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9202 - loss: 0.2155 - mean_iou_metric: 0.7561
# Epoch 196/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9223 - loss: 0.2118 - mean_iou_metric: 0.7571
# Epoch 197/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9242 - loss: 0.2060 - mean_iou_metric: 0.7614
# Epoch 198/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9215 - loss: 0.2085 - mean_iou_metric: 0.7598
# Epoch 199/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9256 - loss: 0.2063 - mean_iou_metric: 0.7657
# Epoch 200/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9271 - loss: 0.1942 - mean_iou_metric: 0.7693
# Epoch 201/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9233 - loss: 0.2055 - mean_iou_metric: 0.7673
# Epoch 202/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9221 - loss: 0.2095 - mean_iou_metric: 0.7595
# Epoch 203/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9257 - loss: 0.2030 - mean_iou_metric: 0.7725
# Epoch 204/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9217 - loss: 0.2187 - mean_iou_metric: 0.7588
# Epoch 205/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9163 - loss: 0.2284 - mean_iou_metric: 0.7445
# Epoch 206/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9159 - loss: 0.2282 - mean_iou_metric: 0.7447
# Epoch 207/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9008 - loss: 0.2643 - mean_iou_metric: 0.7237
# Epoch 208/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7083 - loss: 15.1139 - mean_iou_metric: 0.4872
# Epoch 209/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3781 - loss: 2.0496 - mean_iou_metric: 0.1318
# Epoch 210/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4669 - loss: 1.2338 - mean_iou_metric: 0.1930
# Epoch 211/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4398 - loss: 1.1969 - mean_iou_metric: 0.1812
# Epoch 212/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.4887 - loss: 1.1415 - mean_iou_metric: 0.2335
# Epoch 213/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5419 - loss: 1.0633 - mean_iou_metric: 0.2597
# Epoch 214/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5627 - loss: 1.0037 - mean_iou_metric: 0.2806
# Epoch 215/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5661 - loss: 1.0012 - mean_iou_metric: 0.2888
# Epoch 216/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5015 - loss: 1.0983 - mean_iou_metric: 0.2359
# Epoch 217/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5395 - loss: 1.0287 - mean_iou_metric: 0.2869
# Epoch 218/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5903 - loss: 0.9510 - mean_iou_metric: 0.2873
# Epoch 219/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5843 - loss: 0.9427 - mean_iou_metric: 0.2772
# Epoch 220/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6097 - loss: 0.8773 - mean_iou_metric: 0.3091
# Epoch 221/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6291 - loss: 0.8261 - mean_iou_metric: 0.3262
# Epoch 222/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6211 - loss: 0.8145 - mean_iou_metric: 0.3218
# Epoch 223/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6165 - loss: 0.8336 - mean_iou_metric: 0.3197
# Epoch 224/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6088 - loss: 0.8617 - mean_iou_metric: 0.3119
# Epoch 225/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6377 - loss: 0.7907 - mean_iou_metric: 0.3323
# Epoch 226/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6278 - loss: 0.8107 - mean_iou_metric: 0.3261
# Epoch 227/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6305 - loss: 0.7842 - mean_iou_metric: 0.3306
# Epoch 228/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6333 - loss: 0.7655 - mean_iou_metric: 0.3388
# Epoch 229/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6287 - loss: 0.7719 - mean_iou_metric: 0.3450
# Epoch 230/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6178 - loss: 0.7774 - mean_iou_metric: 0.3438
# Epoch 231/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6345 - loss: 0.7625 - mean_iou_metric: 0.3517
# Epoch 232/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6235 - loss: 0.8373 - mean_iou_metric: 0.3286
# Epoch 233/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6250 - loss: 0.8564 - mean_iou_metric: 0.3288
# Epoch 234/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5804 - loss: 0.8689 - mean_iou_metric: 0.3046
# Epoch 235/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6090 - loss: 0.8593 - mean_iou_metric: 0.3633
# Epoch 236/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6337 - loss: 0.7649 - mean_iou_metric: 0.3482
# Epoch 237/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6350 - loss: 0.7969 - mean_iou_metric: 0.3385
# Epoch 238/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6312 - loss: 0.7831 - mean_iou_metric: 0.3521
# Epoch 239/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6253 - loss: 0.7626 - mean_iou_metric: 0.3503
# Epoch 240/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6279 - loss: 0.7711 - mean_iou_metric: 0.3534
# Epoch 241/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6437 - loss: 0.7387 - mean_iou_metric: 0.3516
# Epoch 242/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6556 - loss: 0.7166 - mean_iou_metric: 0.3669
# Epoch 243/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6528 - loss: 0.7260 - mean_iou_metric: 0.3643
# Epoch 244/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6480 - loss: 0.7359 - mean_iou_metric: 0.3658
# Epoch 245/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6308 - loss: 0.7483 - mean_iou_metric: 0.3553
# Epoch 246/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6418 - loss: 0.7228 - mean_iou_metric: 0.3852
# Epoch 247/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6411 - loss: 0.7346 - mean_iou_metric: 0.3764
# Epoch 248/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6350 - loss: 0.7532 - mean_iou_metric: 0.3794
# Epoch 249/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6394 - loss: 0.7376 - mean_iou_metric: 0.3705
# Epoch 250/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6348 - loss: 0.7125 - mean_iou_metric: 0.3815
# Epoch 251/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6544 - loss: 0.6876 - mean_iou_metric: 0.3919
# Epoch 252/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6576 - loss: 0.6856 - mean_iou_metric: 0.3871
# Epoch 253/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6612 - loss: 0.6757 - mean_iou_metric: 0.4006
# Epoch 254/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6657 - loss: 0.6885 - mean_iou_metric: 0.3949
# Epoch 255/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6584 - loss: 0.7013 - mean_iou_metric: 0.3929
# Epoch 256/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6744 - loss: 0.6730 - mean_iou_metric: 0.4098
# Epoch 257/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6827 - loss: 0.6676 - mean_iou_metric: 0.4220
# Epoch 258/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6800 - loss: 0.6694 - mean_iou_metric: 0.4104
# Epoch 259/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6579 - loss: 0.6831 - mean_iou_metric: 0.4090
# Epoch 260/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6993 - loss: 0.6696 - mean_iou_metric: 0.4329
# Epoch 261/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6651 - loss: 0.6966 - mean_iou_metric: 0.4009
# Epoch 262/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6320 - loss: 0.7152 - mean_iou_metric: 0.3851
# Epoch 263/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6663 - loss: 0.6974 - mean_iou_metric: 0.4177
# Epoch 264/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6740 - loss: 0.6759 - mean_iou_metric: 0.4024
# Epoch 265/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6495 - loss: 0.7176 - mean_iou_metric: 0.3774
# Epoch 266/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6668 - loss: 0.7101 - mean_iou_metric: 0.4094
# Epoch 267/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6751 - loss: 0.6937 - mean_iou_metric: 0.4106
# Epoch 268/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7003 - loss: 0.6755 - mean_iou_metric: 0.4441
# Epoch 269/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7131 - loss: 0.6706 - mean_iou_metric: 0.4365
# Epoch 270/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7112 - loss: 0.6608 - mean_iou_metric: 0.4438
# Epoch 271/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7013 - loss: 0.6817 - mean_iou_metric: 0.4183
# Epoch 272/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7114 - loss: 0.6689 - mean_iou_metric: 0.4534
# Epoch 273/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7219 - loss: 0.6482 - mean_iou_metric: 0.4417
# Epoch 274/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7272 - loss: 0.6485 - mean_iou_metric: 0.4566
# Epoch 275/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7361 - loss: 0.6235 - mean_iou_metric: 0.4549
# Epoch 276/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7176 - loss: 0.6518 - mean_iou_metric: 0.4463
# Epoch 277/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7385 - loss: 0.6112 - mean_iou_metric: 0.4649
# Epoch 278/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7442 - loss: 0.5986 - mean_iou_metric: 0.4755
# Epoch 279/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7367 - loss: 0.6077 - mean_iou_metric: 0.4716
# Epoch 280/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7501 - loss: 0.5879 - mean_iou_metric: 0.4755
# Epoch 281/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7405 - loss: 0.5961 - mean_iou_metric: 0.4715
# Epoch 282/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7497 - loss: 0.5849 - mean_iou_metric: 0.4768
# Epoch 283/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7519 - loss: 0.5796 - mean_iou_metric: 0.4845
# Epoch 284/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7588 - loss: 0.5645 - mean_iou_metric: 0.4847
# Epoch 285/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7651 - loss: 0.5565 - mean_iou_metric: 0.4953
# Epoch 286/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7222 - loss: 0.6316 - mean_iou_metric: 0.4597
# Epoch 287/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7324 - loss: 0.6212 - mean_iou_metric: 0.4638
# Epoch 288/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7434 - loss: 0.6108 - mean_iou_metric: 0.4812
# Epoch 289/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7453 - loss: 0.5939 - mean_iou_metric: 0.4812
# Epoch 290/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7560 - loss: 0.5748 - mean_iou_metric: 0.4868
# Epoch 291/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7096 - loss: 0.6533 - mean_iou_metric: 0.4654
# Epoch 292/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7328 - loss: 0.6470 - mean_iou_metric: 0.4494
# Epoch 293/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6884 - loss: 0.7134 - mean_iou_metric: 0.4254
# Epoch 294/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7102 - loss: 0.6887 - mean_iou_metric: 0.4303
# Epoch 295/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7377 - loss: 0.6312 - mean_iou_metric: 0.4810
# Epoch 296/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7396 - loss: 0.6312 - mean_iou_metric: 0.4501
# Epoch 297/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7500 - loss: 0.6123 - mean_iou_metric: 0.4821
# Epoch 298/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7689 - loss: 0.5518 - mean_iou_metric: 0.4787
# Epoch 299/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7692 - loss: 0.5511 - mean_iou_metric: 0.4887
# Epoch 300/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7480 - loss: 0.5834 - mean_iou_metric: 0.4708
# Epoch 301/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7336 - loss: 0.6137 - mean_iou_metric: 0.4659
# Epoch 302/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6988 - loss: 0.6444 - mean_iou_metric: 0.4377
# Epoch 303/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7093 - loss: 0.6407 - mean_iou_metric: 0.4565
# Epoch 304/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7414 - loss: 0.6096 - mean_iou_metric: 0.4716
# Epoch 305/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7680 - loss: 0.5629 - mean_iou_metric: 0.4989
# Epoch 306/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7567 - loss: 0.5795 - mean_iou_metric: 0.4783
# Epoch 307/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7736 - loss: 0.5537 - mean_iou_metric: 0.5052
# Epoch 308/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7699 - loss: 0.5451 - mean_iou_metric: 0.4939
# Epoch 309/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7761 - loss: 0.5280 - mean_iou_metric: 0.5069
# Epoch 310/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7850 - loss: 0.5160 - mean_iou_metric: 0.5169
# Epoch 311/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7827 - loss: 0.5124 - mean_iou_metric: 0.5139
# Epoch 312/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7799 - loss: 0.5225 - mean_iou_metric: 0.5111
# Epoch 313/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7711 - loss: 0.5472 - mean_iou_metric: 0.5091
# Epoch 314/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7729 - loss: 0.5324 - mean_iou_metric: 0.5064
# Epoch 315/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7861 - loss: 0.5120 - mean_iou_metric: 0.5216
# Epoch 316/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7895 - loss: 0.5016 - mean_iou_metric: 0.5181
# Epoch 317/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7823 - loss: 0.5271 - mean_iou_metric: 0.5155
# Epoch 318/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7782 - loss: 0.5305 - mean_iou_metric: 0.5131
# Epoch 319/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7831 - loss: 0.5143 - mean_iou_metric: 0.5207
# Epoch 320/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7888 - loss: 0.5002 - mean_iou_metric: 0.5249
# Epoch 321/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7855 - loss: 0.5094 - mean_iou_metric: 0.5161
# Epoch 322/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7806 - loss: 0.5162 - mean_iou_metric: 0.5212
# Epoch 323/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7911 - loss: 0.4993 - mean_iou_metric: 0.5294
# Epoch 324/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7861 - loss: 0.5126 - mean_iou_metric: 0.5280
# Epoch 325/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7805 - loss: 0.5404 - mean_iou_metric: 0.5101
# Epoch 326/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7854 - loss: 0.5139 - mean_iou_metric: 0.5224
# Epoch 327/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7763 - loss: 0.5717 - mean_iou_metric: 0.5070
# Epoch 328/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7889 - loss: 0.5074 - mean_iou_metric: 0.5295
# Epoch 329/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7883 - loss: 0.5038 - mean_iou_metric: 0.5163
# Epoch 330/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7878 - loss: 0.5101 - mean_iou_metric: 0.5204
# Epoch 331/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7860 - loss: 0.5085 - mean_iou_metric: 0.5155
# Epoch 332/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7897 - loss: 0.5051 - mean_iou_metric: 0.5284
# Epoch 333/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7812 - loss: 0.5160 - mean_iou_metric: 0.5130
# Epoch 334/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7847 - loss: 0.5114 - mean_iou_metric: 0.5234
# Epoch 335/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7827 - loss: 0.5356 - mean_iou_metric: 0.5198
# Epoch 336/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7854 - loss: 0.5175 - mean_iou_metric: 0.5227
# Epoch 337/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7871 - loss: 0.5187 - mean_iou_metric: 0.5181
# Epoch 338/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7878 - loss: 0.5085 - mean_iou_metric: 0.5247
# Epoch 339/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7876 - loss: 0.5155 - mean_iou_metric: 0.5147
# Epoch 340/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7904 - loss: 0.5022 - mean_iou_metric: 0.5289
# Epoch 341/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7880 - loss: 0.5139 - mean_iou_metric: 0.5197
# Epoch 342/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7793 - loss: 0.5379 - mean_iou_metric: 0.5170
# Epoch 343/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7875 - loss: 0.5069 - mean_iou_metric: 0.5282
# Epoch 344/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7718 - loss: 0.5273 - mean_iou_metric: 0.5038
# Epoch 345/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7823 - loss: 0.5212 - mean_iou_metric: 0.5272
# Epoch 346/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7930 - loss: 0.4982 - mean_iou_metric: 0.5300
# Epoch 347/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7861 - loss: 0.5264 - mean_iou_metric: 0.5302
# Epoch 348/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7792 - loss: 0.5294 - mean_iou_metric: 0.5099
# Epoch 349/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8037 - loss: 0.4699 - mean_iou_metric: 0.5480
# Epoch 350/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8010 - loss: 0.4789 - mean_iou_metric: 0.5375
# Epoch 351/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7970 - loss: 0.4788 - mean_iou_metric: 0.5369
# Epoch 352/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7990 - loss: 0.4760 - mean_iou_metric: 0.5313
# Epoch 353/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7935 - loss: 0.4882 - mean_iou_metric: 0.5394
# Epoch 354/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7924 - loss: 0.4977 - mean_iou_metric: 0.5361
# Epoch 355/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8011 - loss: 0.4746 - mean_iou_metric: 0.5441
# Epoch 356/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8009 - loss: 0.4822 - mean_iou_metric: 0.5446
# Epoch 357/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7977 - loss: 0.4765 - mean_iou_metric: 0.5395
# Epoch 358/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7982 - loss: 0.4787 - mean_iou_metric: 0.5396
# Epoch 359/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7954 - loss: 0.4867 - mean_iou_metric: 0.5440
# Epoch 360/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7951 - loss: 0.4896 - mean_iou_metric: 0.5322
# Epoch 361/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7960 - loss: 0.4914 - mean_iou_metric: 0.5444
# Epoch 362/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8029 - loss: 0.4676 - mean_iou_metric: 0.5445
# Epoch 363/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7994 - loss: 0.4727 - mean_iou_metric: 0.5394
# Epoch 364/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8080 - loss: 0.4745 - mean_iou_metric: 0.5574
# Epoch 365/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8057 - loss: 0.4690 - mean_iou_metric: 0.5547
# Epoch 366/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7994 - loss: 0.4796 - mean_iou_metric: 0.5423
# Epoch 367/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8039 - loss: 0.4670 - mean_iou_metric: 0.5580
# Epoch 368/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8039 - loss: 0.4634 - mean_iou_metric: 0.5509
# Epoch 369/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8088 - loss: 0.4539 - mean_iou_metric: 0.5548
# Epoch 370/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8119 - loss: 0.4497 - mean_iou_metric: 0.5669
# Epoch 371/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8114 - loss: 0.4553 - mean_iou_metric: 0.5623
# Epoch 372/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8146 - loss: 0.4480 - mean_iou_metric: 0.5748
# Epoch 373/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8034 - loss: 0.4654 - mean_iou_metric: 0.5474
# Epoch 374/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8175 - loss: 0.4377 - mean_iou_metric: 0.5683
# Epoch 375/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8179 - loss: 0.4350 - mean_iou_metric: 0.5751
# Epoch 376/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8130 - loss: 0.4476 - mean_iou_metric: 0.5713
# Epoch 377/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8176 - loss: 0.4424 - mean_iou_metric: 0.5726
# Epoch 378/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8182 - loss: 0.4382 - mean_iou_metric: 0.5780
# Epoch 379/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8162 - loss: 0.4408 - mean_iou_metric: 0.5739
# Epoch 380/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8186 - loss: 0.4341 - mean_iou_metric: 0.5799
# Epoch 381/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8178 - loss: 0.4478 - mean_iou_metric: 0.5691
# Epoch 382/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8224 - loss: 0.4298 - mean_iou_metric: 0.5853
# Epoch 383/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8191 - loss: 0.4357 - mean_iou_metric: 0.5789
# Epoch 384/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8190 - loss: 0.4376 - mean_iou_metric: 0.5814
# Epoch 385/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7923 - loss: 0.5077 - mean_iou_metric: 0.5339
# Epoch 386/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7913 - loss: 0.5171 - mean_iou_metric: 0.5443
# Epoch 387/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7910 - loss: 0.5043 - mean_iou_metric: 0.5252
# Epoch 388/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7853 - loss: 0.5117 - mean_iou_metric: 0.5280
# Epoch 389/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8013 - loss: 0.5015 - mean_iou_metric: 0.5344
# Epoch 390/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8072 - loss: 0.4660 - mean_iou_metric: 0.5486
# Epoch 391/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8172 - loss: 0.4461 - mean_iou_metric: 0.5647
# Epoch 392/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8178 - loss: 0.4377 - mean_iou_metric: 0.5757
# Epoch 393/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8147 - loss: 0.4491 - mean_iou_metric: 0.5654
# Epoch 394/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8242 - loss: 0.4251 - mean_iou_metric: 0.5845
# Epoch 395/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8172 - loss: 0.4438 - mean_iou_metric: 0.5729
# Epoch 396/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8183 - loss: 0.4448 - mean_iou_metric: 0.5736
# Epoch 397/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8104 - loss: 0.4593 - mean_iou_metric: 0.5728
# Epoch 398/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8176 - loss: 0.4459 - mean_iou_metric: 0.5696
# Epoch 399/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8270 - loss: 0.4233 - mean_iou_metric: 0.5854
# Epoch 400/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8263 - loss: 0.4183 - mean_iou_metric: 0.5941
# Epoch 401/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8240 - loss: 0.4275 - mean_iou_metric: 0.5841
# Epoch 402/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8317 - loss: 0.4120 - mean_iou_metric: 0.5936
# Epoch 403/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8315 - loss: 0.4185 - mean_iou_metric: 0.5964
# Epoch 404/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8262 - loss: 0.4261 - mean_iou_metric: 0.5960
# Epoch 405/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8198 - loss: 0.4518 - mean_iou_metric: 0.5789
# Epoch 406/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8252 - loss: 0.4349 - mean_iou_metric: 0.5823
# Epoch 407/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8291 - loss: 0.4208 - mean_iou_metric: 0.5889
# Epoch 408/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8366 - loss: 0.4047 - mean_iou_metric: 0.6080
# Epoch 409/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8329 - loss: 0.4077 - mean_iou_metric: 0.6046
# Epoch 410/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8385 - loss: 0.3990 - mean_iou_metric: 0.6109
# Epoch 411/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8361 - loss: 0.4029 - mean_iou_metric: 0.6095
# Epoch 412/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8375 - loss: 0.3985 - mean_iou_metric: 0.6110
# Epoch 413/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8392 - loss: 0.4005 - mean_iou_metric: 0.6161
# Epoch 414/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8346 - loss: 0.4086 - mean_iou_metric: 0.6035
# Epoch 415/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8403 - loss: 0.4005 - mean_iou_metric: 0.6206
# Epoch 416/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8300 - loss: 0.4141 - mean_iou_metric: 0.5951
# Epoch 417/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8342 - loss: 0.4067 - mean_iou_metric: 0.6101
# Epoch 418/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8377 - loss: 0.3959 - mean_iou_metric: 0.6139
# Epoch 419/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8315 - loss: 0.4179 - mean_iou_metric: 0.6036
# Epoch 420/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8464 - loss: 0.3921 - mean_iou_metric: 0.6266
# Epoch 421/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8432 - loss: 0.3905 - mean_iou_metric: 0.6182
# Epoch 422/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8379 - loss: 0.4061 - mean_iou_metric: 0.6115
# Epoch 423/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8439 - loss: 0.3936 - mean_iou_metric: 0.6085
# Epoch 424/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8479 - loss: 0.3862 - mean_iou_metric: 0.6290
# Epoch 425/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8404 - loss: 0.4011 - mean_iou_metric: 0.6170
# Epoch 426/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8544 - loss: 0.3750 - mean_iou_metric: 0.6384
# Epoch 427/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8461 - loss: 0.3886 - mean_iou_metric: 0.6262
# Epoch 428/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8471 - loss: 0.3872 - mean_iou_metric: 0.6129
# Epoch 429/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8448 - loss: 0.3878 - mean_iou_metric: 0.6286
# Epoch 430/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8504 - loss: 0.3789 - mean_iou_metric: 0.6308
# Epoch 431/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8543 - loss: 0.3721 - mean_iou_metric: 0.6358
# Epoch 432/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8557 - loss: 0.3652 - mean_iou_metric: 0.6418
# Epoch 433/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8551 - loss: 0.3688 - mean_iou_metric: 0.6431
# Epoch 434/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8535 - loss: 0.3705 - mean_iou_metric: 0.6386
# Epoch 435/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8537 - loss: 0.3730 - mean_iou_metric: 0.6440
# Epoch 436/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8544 - loss: 0.3710 - mean_iou_metric: 0.6373
# Epoch 437/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8562 - loss: 0.3644 - mean_iou_metric: 0.6473
# Epoch 438/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8607 - loss: 0.3519 - mean_iou_metric: 0.6489
# Epoch 439/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8540 - loss: 0.3624 - mean_iou_metric: 0.6389
# Epoch 440/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8565 - loss: 0.3660 - mean_iou_metric: 0.6465
# Epoch 441/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8557 - loss: 0.3650 - mean_iou_metric: 0.6464
# Epoch 442/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8547 - loss: 0.3728 - mean_iou_metric: 0.6426
# Epoch 443/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8571 - loss: 0.3619 - mean_iou_metric: 0.6353
# Epoch 444/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8464 - loss: 0.3883 - mean_iou_metric: 0.6285
# Epoch 445/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8443 - loss: 0.4081 - mean_iou_metric: 0.6207
# Epoch 446/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8188 - loss: 0.4450 - mean_iou_metric: 0.5924
# Epoch 447/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8453 - loss: 0.3920 - mean_iou_metric: 0.6245
# Epoch 448/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8464 - loss: 0.3918 - mean_iou_metric: 0.6170
# Epoch 449/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8338 - loss: 0.4329 - mean_iou_metric: 0.5951
# Epoch 450/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8122 - loss: 0.4656 - mean_iou_metric: 0.5900
# Epoch 451/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8149 - loss: 0.4664 - mean_iou_metric: 0.5586
# Epoch 452/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7755 - loss: 0.5097 - mean_iou_metric: 0.5490
# Epoch 453/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8110 - loss: 0.5100 - mean_iou_metric: 0.5466
# Epoch 454/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8435 - loss: 0.4085 - mean_iou_metric: 0.6170
# Epoch 455/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8402 - loss: 0.4105 - mean_iou_metric: 0.6088
# Epoch 456/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8508 - loss: 0.3848 - mean_iou_metric: 0.6335
# Epoch 457/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8535 - loss: 0.3777 - mean_iou_metric: 0.6306
# Epoch 458/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8501 - loss: 0.3781 - mean_iou_metric: 0.6397
# Epoch 459/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8603 - loss: 0.3612 - mean_iou_metric: 0.6508
# Epoch 460/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8606 - loss: 0.3550 - mean_iou_metric: 0.6487
# Epoch 461/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8684 - loss: 0.3373 - mean_iou_metric: 0.6617
# Epoch 462/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8671 - loss: 0.3425 - mean_iou_metric: 0.6672
# Epoch 463/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8591 - loss: 0.3512 - mean_iou_metric: 0.6497
# Epoch 464/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8667 - loss: 0.3462 - mean_iou_metric: 0.6571
# Epoch 465/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8682 - loss: 0.3397 - mean_iou_metric: 0.6621
# Epoch 466/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8657 - loss: 0.3388 - mean_iou_metric: 0.6632
# Epoch 467/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8698 - loss: 0.3372 - mean_iou_metric: 0.6636
# Epoch 468/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8716 - loss: 0.3261 - mean_iou_metric: 0.6654
# Epoch 469/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8736 - loss: 0.3232 - mean_iou_metric: 0.6779
# Epoch 470/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8744 - loss: 0.3271 - mean_iou_metric: 0.6674
# Epoch 471/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8730 - loss: 0.3241 - mean_iou_metric: 0.6730
# Epoch 472/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8789 - loss: 0.3215 - mean_iou_metric: 0.6823
# Epoch 473/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8741 - loss: 0.3205 - mean_iou_metric: 0.6745
# Epoch 474/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8738 - loss: 0.3253 - mean_iou_metric: 0.6630
# Epoch 475/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8795 - loss: 0.3135 - mean_iou_metric: 0.6791
# Epoch 476/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8797 - loss: 0.3101 - mean_iou_metric: 0.6840
# Epoch 477/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8769 - loss: 0.3186 - mean_iou_metric: 0.6740
# Epoch 478/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8782 - loss: 0.3105 - mean_iou_metric: 0.6830
# Epoch 479/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8874 - loss: 0.2998 - mean_iou_metric: 0.6947
# Epoch 480/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8810 - loss: 0.3075 - mean_iou_metric: 0.6833
# Epoch 481/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8898 - loss: 0.2917 - mean_iou_metric: 0.7019
# Epoch 482/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8774 - loss: 0.3139 - mean_iou_metric: 0.6766
# Epoch 483/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8873 - loss: 0.2949 - mean_iou_metric: 0.6984
# Epoch 484/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8854 - loss: 0.3008 - mean_iou_metric: 0.6914
# Epoch 485/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8815 - loss: 0.3114 - mean_iou_metric: 0.6915
# Epoch 486/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8802 - loss: 0.3118 - mean_iou_metric: 0.6772
# Epoch 487/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8856 - loss: 0.3019 - mean_iou_metric: 0.6930
# Epoch 488/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8845 - loss: 0.3031 - mean_iou_metric: 0.6904
# Epoch 489/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8868 - loss: 0.3032 - mean_iou_metric: 0.6856
# Epoch 490/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8865 - loss: 0.2944 - mean_iou_metric: 0.6993
# Epoch 491/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8919 - loss: 0.2858 - mean_iou_metric: 0.7005
# Epoch 492/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8887 - loss: 0.2911 - mean_iou_metric: 0.6968
# Epoch 493/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8877 - loss: 0.2941 - mean_iou_metric: 0.6956
# Epoch 494/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8863 - loss: 0.2929 - mean_iou_metric: 0.7002
# Epoch 495/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8944 - loss: 0.2825 - mean_iou_metric: 0.7043
# Epoch 496/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8861 - loss: 0.2950 - mean_iou_metric: 0.6915
# Epoch 497/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8883 - loss: 0.2915 - mean_iou_metric: 0.6994
# Epoch 498/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8909 - loss: 0.2868 - mean_iou_metric: 0.7030
# Epoch 499/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8939 - loss: 0.2776 - mean_iou_metric: 0.7098
# Epoch 500/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8933 - loss: 0.2792 - mean_iou_metric: 0.7076

# %%
plt.plot(model_history.history["accuracy"])

# %%
CLASS_COLORS = np.array([
    [0, 0, 0],        # background = black
    [0, 255, 0],      # good = green
    [255, 255, 0],    # fair = yellow
    [255, 0, 0]       # poor = red
], dtype=np.uint8)

def mask_to_color(mask):
    """
    Convert integer mask (0,1,2,3) to RGB color mask
    """
    mask = mask.numpy() if tf.is_tensor(mask) else mask  # convert TF tensor to NumPy
    color_mask = CLASS_COLORS[mask.astype(np.int32)]
    return color_mask

def display(display_list):
    """
    display_list = [input_image, true_mask, predicted_mask]
    """
    plt.figure(figsize=(15, 15))
    titles = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i + 1)
        plt.axis('off')
        plt.title(titles[i])

        if i == 1 or i == 2:  # True mask or predicted mask
            mask = display_list[i]
            if mask.shape[-1] == 1:  # single channel
                mask = mask[..., 0]
            color_mask = mask_to_color(mask)
            plt.imshow(color_mask)
        else:
            plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))

    plt.show()

def create_mask(pred_mask):
    """
    Converts UNet softmax output to integer mask (0,1,2,3)
    """
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0].numpy().astype(np.uint8)

def show_predictions(dataset=None, num=1):
    """
    Displays predictions for the first 'num' batches of a dataset
    """
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = unet.predict(image)
            display([image[0], mask[0], create_mask(pred_mask)])
    else:
        pred_mask = unet.predict(sample_image[tf.newaxis, ...])
        display([sample_image, sample_mask, create_mask(pred_mask)])

# %%
print("----- training_dataset results---------")
show_predictions(train_dataset, 6)
print("----- validation_dataset results---------")
show_predictions(validation_dataset, 6)
# Out:
# ----- training_dataset results---------
# 2026-01-16 20:23:58.981309: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,64,24,32]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:23:59.033709: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,128,24,32]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:23:59.089331: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,128,12,16]{3,2,1,0}, f32[256,128,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:23:59.147326: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,256,12,16]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:23:59.206075: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,512,6,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,256,6,8]{3,2,1,0}, f32[512,256,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:23:59.284648: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,512,6,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,512,6,8]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:23:59.379355: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,512,12,16]{3,2,1,0}, f32[256,512,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2026-01-16 20:23:59.454791: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,256,24,32]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# ----- validation_dataset results---------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 2026-01-16 20:24:02.001362: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# model evaluation
print("Unet Model Evaluation: ")
unet.evaluate(validation_dataset)
# Out:
# Unet Model Evaluation:
# 2026-01-16 20:24:02.497498: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8275 - loss: 0.4615 - mean_iou_metric: 0.6134
# [0.46149206161499023, 0.8275146484375, 0.613429069519043]
