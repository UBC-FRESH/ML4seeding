# %%
import rasterio
with rasterio.open("./data_set/orthomosaic/G15Segment1.tif") as src:
    print("Pixel size (X, Y):", src.res)
    print("CRS:", src.crs)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File ~/venvs/tf220/lib/python3.12/site-packages/rasterio/_base.pyx:320, in rasterio._base.DatasetBase.__init__()
#
# File ~/venvs/tf220/lib/python3.12/site-packages/rasterio/_base.pyx:232, in rasterio._base.open_dataset()
#
# File ~/venvs/tf220/lib/python3.12/site-packages/rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ./data_set/orthomosaic/G15Segment1.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[1], line 2
#       1 import rasterio
# ----> 2 with rasterio.open("./data_set/orthomosaic/G15Segment1.tif") as src:
#       3     print("Pixel size (X, Y):", src.res)
#       4     print("CRS:", src.crs)
#
# ...

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

with rasterio.open("./data_set/orthomosaic/G15Segment1.tif") as src:
    img = src.read([1,2,3])

img = np.transpose(img, (1,2,0))
plt.imshow(img)
plt.title("Ortho")
plt.show()

# %%
import rasterio

with rasterio.open("./data_set/orthomosaic/A58Segment2_roadside.tif") as src:
    print("Pixel size (X, Y):", src.res)
    print("CRS:", src.crs)

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

with rasterio.open("./data_set/orthomosaic/A58Segment2_roadside.tif") as src:
    img = src.read([1,2,3])

img = np.transpose(img, (1,2,0))
plt.imshow(img)
plt.title("Ortho")
plt.show()

# %%
import rasterio

with rasterio.open("./data_set/orthomosaic/A58Segment2.tif") as src:
    print("Pixel size (X, Y):", src.res)
    print("CRS:", src.crs)

# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt

with rasterio.open("./examples/data_set/orthomosaic/A58Segment2.tif") as src:
    img = src.read([1,2,3])

img = np.transpose(img, (1,2,0))
plt.imshow(img)
plt.title("Ortho")
plt.show()
