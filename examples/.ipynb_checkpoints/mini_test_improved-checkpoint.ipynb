# %% [markdown]
# # 1. Import the necessery libraries

# %%
# !sudo nvidia-smi
# Out:
# Wed Nov 19 22:37:31 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.05              Driver Version: 580.95.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Quadro RTX 4000                Off |   00000000:18:00.0 Off |                  N/A |
# | 30%   37C    P8             10W /  125W |    4917MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Quadro RTX 4000                Off |   00000000:3B:00.0 Off |                  N/A |
# | 30%   39C    P8             16W /  125W |    7452MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           89846      C   ...hase02/venvs/tf220/bin/python       3954MiB |
# |    0   N/A  N/A          312415      C   ...salar2/venvs/tf220/bin/python        846MiB |
# |    0   N/A  N/A          356968      C   ...hase02/venvs/tf220/bin/python        108MiB |
# |    1   N/A  N/A           89846      C   ...hase02/venvs/tf220/bin/python         96MiB |
# |    1   N/A  N/A          312415      C   ...salar2/venvs/tf220/bin/python         96MiB |
# |    1   N/A  N/A          356968      C   ...hase02/venvs/tf220/bin/python         96MiB |
# |    1   N/A  N/A          395056      C   ...salar2/venvs/tf220/bin/python       6112MiB |
# |    1   N/A  N/A          470095      C   ...salar2/venvs/tf220/bin/python        824MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# If you want to use the spesific GPU
# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # use GPU 1 or GPU 0

import tensorflow as tf

# List GPUs available
gpus = tf.config.list_physical_devices('GPU')
print("GPUs:", gpus)

# Check if GPUs are available
if gpus:
    print("GPU is available.")
else:
    print("GPU is not available.")

# Set memory growth for each GPU
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 2025-11-19 22:37:32.537458: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-19 22:37:32.592609: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 22:37:33.874738: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# GPU is available.

# %%
import numpy as np
import os
import pandas as pd 
import imageio 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout 
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate
from tensorflow.keras import regularizers

# %% [markdown]
# # 2. Load and split the data

# %%
image_dir = "./data_set/images/"  
mask_dir  = "./data_set/masks/" 

image_filenames = sorted([
    f for f in os.listdir(image_dir)
    if not f.startswith(".") and f.lower().endswith(".jpg")
])

mask_filenames = sorted([
    f for f in os.listdir(mask_dir)
    if not f.startswith(".") and f.lower().endswith(".png")
])

# Check that images and masks match correctly
for img, msk in zip(image_filenames, mask_filenames):
    if img.split('.')[0] != msk.split('.')[0]:
        print("❌ Mismatch:", img, msk)

image_list = [os.path.join(image_dir, f) for f in image_filenames]
mask_list  = [os.path.join(mask_dir,  f) for f in mask_filenames]

# Make the train/validation split dynamic
train_image_list, validation_image_list, train_mask_list, validation_mask_list = \
train_test_split(image_list, mask_list, test_size=0.2, random_state=42)

print("Total images:", len(image_list))
print("image_list:", train_image_list)

print("Total masks:", len(mask_list))
print("mask_list:", train_mask_list)

unique_values = np.unique(imageio.v2.imread(mask_list[0]))
print("Mask classes:", unique_values)
# Out:
# Total images: 8
# image_list: ['./data_set/images/post-harvest_01.jpg', './data_set/images/post-harvest_03_3.jpg', './data_set/images/post-harvest_01_3.jpg', './data_set/images/post-harvest_02_2.jpg', './data_set/images/post-harvest_02.jpg', './data_set/images/post-harvest_03_2.jpg']
# Total masks: 8
# mask_list: ['./data_set/masks/post-harvest_01.png', './data_set/masks/post-harvest_03_3.png', './data_set/masks/post-harvest_01_3.png', './data_set/masks/post-harvest_02_2.png', './data_set/masks/post-harvest_02.png', './data_set/masks/post-harvest_03_2.png']
# Mask classes: [0 1 2 3]

# %% [markdown]
# # 3. explore some images :

# %%
def load_and_plot_image_mask(img_path, mask_path):
    """
    Loads an image and mask, keeps original size, prints shapes, and plots:
        1. Original image
        2. Original mask in color
        3. Overlay of mask on the image

    Args:
        img_path (str): Path to the image file
        mask_path (str): Path to the mask file

    Returns:
        img (tf.Tensor): Normalized image tensor (0-1)
        mask (tf.Tensor): Integer mask tensor
    """
    
    # Define colors for mask classes: background, good, fair, poor
    class_colors = np.array([
        [0, 0, 0],        # 0 = background (black)
        [0, 255, 0],      # 1 = good (green)
        [255, 255, 0],    # 2 = fair (yellow)
        [255, 0, 0]       # 3 = poor (red)
    ], dtype=np.uint8)
    
    # Load image
    img = imageio.imread(img_path)
    img = tf.cast(img, tf.float32) / 255.0  # normalize to 0-1
    
    # Load mask
    mask = imageio.imread(mask_path)
    mask = tf.cast(mask[..., np.newaxis], tf.uint8)[...,0].numpy()  # keep integers
    
    # Print shapes
    print("Image shape:", img.shape)
    print("Mask shape:", mask.shape)
    
    # Convert mask to color
    mask_color = class_colors[mask]
    
    # Plotting
    fig, ax = plt.subplots(1, 3, figsize=(20, 10))
    
    # Original image
    ax[0].imshow(img)
    ax[0].set_title("Original Image")
    ax[0].axis('on')
    
    # Original mask in color
    ax[1].imshow(mask_color)
    ax[1].set_title("Original Mask (Color)")
    ax[1].axis('on')
    
    # Overlay
    overlay = (0.6 * img.numpy() + 0.4 * mask_color / 255.0)
    ax[2].imshow(overlay)
    ax[2].set_title("Overlay")
    ax[2].axis('on')
    
    plt.show()
    
    # Print unique mask values for sanity check
    print("Unique mask values:", np.unique(mask))
    
    return img, mask

# %%
n = 1
img, mask = load_and_plot_image_mask(train_image_list[n], train_mask_list[n])
# Out:
# /tmp/ipykernel_1586513/2670707206.py:26: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(img_path)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763591856.209412 1586513 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1723 MB memory:  -> device: 0, name: Quadro RTX 4000, pci bus id: 0000:18:00.0, compute capability: 7.5
# I0000 00:00:1763591856.211120 1586513 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 204 MB memory:  -> device: 1, name: Quadro RTX 4000, pci bus id: 0000:3b:00.0, compute capability: 7.5
# /tmp/ipykernel_1586513/2670707206.py:30: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mask = imageio.imread(mask_path)
# Image shape: (312, 312, 3)
# Mask shape: (312, 312)
# Unique mask values: [0 1 2 3]

# %%
train_images = tf.constant(train_image_list)
train_masks = tf.constant(train_mask_list)

train_dataset = tf.data.Dataset.from_tensor_slices((train_images,train_masks))
for image,mask in train_dataset.take(1) : 
    print(image)
    print(mask)
    
validation_images = tf.constant(validation_image_list)
validation_masks = tf.constant(validation_mask_list)

validation_dataset = tf.data.Dataset.from_tensor_slices((validation_images,validation_masks))
for image,mask in validation_dataset.take(1) : 
    print(image)
    print(mask)
# Out:
# tf.Tensor(b'./data_set/images/post-harvest_01.jpg', shape=(), dtype=string)
# tf.Tensor(b'./data_set/masks/post-harvest_01.png', shape=(), dtype=string)
# tf.Tensor(b'./data_set/images/post-harvest_01_2.jpg', shape=(), dtype=string)
# tf.Tensor(b'./data_set/masks/post-harvest_01_2.png', shape=(), dtype=string)
# 2025-11-19 22:37:36.776562: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-11-19 22:37:36.793660: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # 4. preprocessing our data

# %%
def process_path(image_path,mask_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img,channels=3)
    img = tf.image.convert_image_dtype(img,tf.float32) #this do the same as dividing by 255 to set the values between 0 and 1 (normalization)    
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask,channels=3)
    mask = tf.math.reduce_max(mask,axis=-1,keepdims=True)
    return img , mask

def preprocess(image,mask) : 
    input_image = tf.image.resize(image,(96,128),method='nearest') # consider keeping higher resolution (e.g., 256×256) if GPU memory allows.
    input_mask = tf.image.resize(mask,(96,128),method='nearest')    
    return input_image , input_mask

train_image_ds = train_dataset.map(process_path) # apply the preprocces_path function to our train_dataset
print(train_image_ds)
train_processed_image_ds = train_image_ds.map(preprocess) # apply the preprocess function to our train_dataset

validation_image_ds = validation_dataset.map(process_path) # apply the preprocces_path function to our validation_dataset
print(validation_image_ds)
validation_processed_image_ds = validation_image_ds.map(preprocess)
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.uint8, name=None))>
# <_MapDataset element_spec=(TensorSpec(shape=(None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.uint8, name=None))>

# %%
# Add data augmentation (flips, rotations)
# def augment(image, mask):
#     if tf.random.uniform(()) > 0.5:
#         image = tf.image.flip_left_right(image)
#         mask = tf.image.flip_left_right(mask)
#     return image, mask
# train_processed_image_ds = train_processed_image_ds.map(augment)

# %% [markdown]
# # 5.  Define The Conv Block For The Contracting Path

# %%
def conv_block(inputs=None, n_filters=32, dropout_prob=0, max_pooling=True):
    
    conv = Conv2D(n_filters, 
                  kernel_size = 3,     
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(inputs)
    conv = Conv2D(n_filters, 
                  kernel_size = 3, 
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(conv)
   
    

    if dropout_prob > 0:
        conv = Dropout(dropout_prob)(conv)
        
    if max_pooling:
        next_layer = MaxPooling2D(pool_size=(2,2))(conv)
        
        
    else:
        next_layer = conv
        
    skip_connection = conv
    
    return next_layer, skip_connection

# %% [markdown]
# # 6. Define the upsampling block for the expanding path

# %%
def upsampling_block(expansive_input, contractive_input, n_filters=32):
    
    up = Conv2DTranspose(
                 n_filters,  
                 kernel_size = 3,
                 strides=(2,2),
                 padding='same')(expansive_input)
    
    merge = concatenate([up, contractive_input], axis=3)
    conv = Conv2D(n_filters,  
                 kernel_size = 3,   
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(merge)
    conv = Conv2D(n_filters,  
                 kernel_size = 3,  
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(conv)
        
    return conv

# %% [markdown]
# # 7. Finally! ,  we will Define the unet model
# ## which composes of a set of conv blocks and upsampling blocks

# %%
def unet_model(input_size=(96, 128, 3), n_filters=32, n_classes=4):
    
    inputs = Input(input_size)
    
    # contracting path
    cblock1 = conv_block(inputs, n_filters, dropout_prob=0.4)
    cblock2 = conv_block(cblock1[0], 2*n_filters, dropout_prob=0.4)
    cblock3 = conv_block(cblock2[0], 4*n_filters, dropout_prob=0.4)
    cblock4 = conv_block(cblock3[0], 8*n_filters, dropout_prob=0.45) 
    cblock5 = conv_block(cblock4[0],16*n_filters, dropout_prob=0.4, max_pooling=None)     
    
    # expanding path
    ublock6 = upsampling_block(cblock5[0], cblock4[1],  8 * n_filters)
    ublock7 = upsampling_block(ublock6, cblock3[1],  n_filters*4)
    ublock8 = upsampling_block(ublock7,cblock2[1] , n_filters*2)
    ublock9 = upsampling_block(ublock8,cblock1[1],  n_filters)

    conv9 = Conv2D(n_filters,
                 3,
                 activation='relu',
                 padding='same',
                 kernel_initializer='he_normal')(ublock9)
    
    conv10 = Conv2D(n_classes, kernel_size=1, activation='softmax', padding='same')(conv9)
    # conv10 = Conv2D(n_classes, kernel_size=1, padding='same')(conv9)  

    model = tf.keras.Model(inputs=inputs, outputs=conv10)

    return model

# %%
img_height = 96
img_width = 128
num_channels = 3

unet = unet_model((img_height, img_width, num_channels))

# %% [markdown]
# # 8. Our model is ready !!

# %%
unet.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 96, 128,   │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 96, 128,   │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 96, 128,   │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 96, 128,   │          0 │ conv2d_1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 48, 64,    │          0 │ dropout[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 48, 64,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 48, 64,    │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 48, 64,    │          0 │ conv2d_3[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 24, 32,    │          0 │ dropout_1[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 24, 32,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 24, 32,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 24, 32,    │          0 │ conv2d_5[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 12, 16,    │          0 │ dropout_2[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 12, 16,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 12, 16,    │    590,080 │ conv2d_6[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 12, 16,    │          0 │ conv2d_7[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 6, 8, 256) │          0 │ dropout_3[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 6, 8, 512) │  1,180,160 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 6, 8, 512) │  2,359,808 │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 6, 8, 512) │          0 │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 12, 16,    │  1,179,904 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 12, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 12, 16,    │  1,179,904 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 12, 16,    │    590,080 │ conv2d_10[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 24, 32,    │    295,040 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 24, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 24, 32,    │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 24, 32,    │    147,584 │ conv2d_12[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 48, 64,    │     73,792 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 48, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 48, 64,    │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 48, 64,    │     36,928 │ conv2d_14[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 96, 128,   │     18,464 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 96, 128,   │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 96, 128,   │     18,464 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 96, 128,   │      9,248 │ conv2d_16[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 96, 128,   │      9,248 │ conv2d_17[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 96, 128,   │        132 │ conv2d_18[0][0]   │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,639,844 (32.96 MB)
#  Trainable params: 8,639,844 (32.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
unet.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
EPOCHS = 100
BUFFER_SIZE = 390
BATCH_SIZE = 2

# train
# train_processed_image_ds.batch(BATCH_SIZE)
train_dataset = train_processed_image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
print(train_processed_image_ds.element_spec)

# validation
# validation_processed_image_ds.batch(BATCH_SIZE)
# validation_dataset = validation_processed_image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
validation_dataset = validation_processed_image_ds.cache().batch(BATCH_SIZE)

print(validation_processed_image_ds.element_spec)
 

model_history = unet.fit(train_dataset, epochs=EPOCHS)
# Out:
# (TensorSpec(shape=(96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(96, 128, 1), dtype=tf.uint8, name=None))
# (TensorSpec(shape=(96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(96, 128, 1), dtype=tf.uint8, name=None))
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7366 - loss: 0.9671
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5644 - loss: 0.9851
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6118 - loss: 0.8308
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6298 - loss: 0.9482
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6566 - loss: 0.8030
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6084 - loss: 0.7957
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6477 - loss: 0.7282
# Epoch 8/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6479 - loss: 0.7275
# Epoch 9/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6630 - loss: 0.7046
# Epoch 10/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6649 - loss: 0.6982
# Epoch 11/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6702 - loss: 0.6813
# Epoch 12/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6733 - loss: 0.6766
# Epoch 13/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6727 - loss: 0.6708
# Epoch 14/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6782 - loss: 0.6576
# Epoch 15/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6733 - loss: 0.6612
# Epoch 16/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6783 - loss: 0.6360
# Epoch 17/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6813 - loss: 0.6384
# Epoch 18/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6862 - loss: 0.6256
# Epoch 19/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6896 - loss: 0.6103
# Epoch 20/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6850 - loss: 0.6132
# Epoch 21/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7052 - loss: 0.6000
# Epoch 22/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7027 - loss: 0.5916
# Epoch 23/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6898 - loss: 0.5989
# Epoch 24/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7487 - loss: 0.5752
# Epoch 25/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7737 - loss: 0.5577
# Epoch 26/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7255 - loss: 0.5875
# Epoch 27/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7846 - loss: 0.5672
# Epoch 28/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7694 - loss: 0.5495
# Epoch 29/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7771 - loss: 0.5457
# Epoch 30/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7840 - loss: 0.5411
# Epoch 31/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8083 - loss: 0.4999
# Epoch 32/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8122 - loss: 0.4832
# Epoch 33/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7945 - loss: 0.4962
# Epoch 34/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7888 - loss: 0.4938
# Epoch 35/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8213 - loss: 0.4529
# Epoch 36/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8007 - loss: 0.4881
# Epoch 37/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7788 - loss: 0.5015
# Epoch 38/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7911 - loss: 0.5181
# Epoch 39/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7953 - loss: 0.5169
# Epoch 40/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7495 - loss: 0.5602
# Epoch 41/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8382 - loss: 0.4467
# Epoch 42/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7762 - loss: 0.5140
# Epoch 43/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8274 - loss: 0.4645
# Epoch 44/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8164 - loss: 0.4783
# Epoch 45/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8320 - loss: 0.4333
# Epoch 46/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8290 - loss: 0.4371
# Epoch 47/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8517 - loss: 0.3931
# Epoch 48/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8570 - loss: 0.3818
# Epoch 49/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8561 - loss: 0.3759
# Epoch 50/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8480 - loss: 0.3986
# Epoch 51/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8623 - loss: 0.3578
# Epoch 52/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8638 - loss: 0.3526
# Epoch 53/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8763 - loss: 0.3270
# Epoch 54/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8775 - loss: 0.3299
# Epoch 55/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8781 - loss: 0.3258
# Epoch 56/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8801 - loss: 0.3226
# Epoch 57/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8822 - loss: 0.3058
# Epoch 58/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8760 - loss: 0.3198
# Epoch 59/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8461 - loss: 0.4626
# Epoch 60/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8402 - loss: 0.4430
# Epoch 61/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7904 - loss: 0.5178
# Epoch 62/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8506 - loss: 0.4182
# Epoch 63/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8475 - loss: 0.4000
# Epoch 64/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8691 - loss: 0.3623
# Epoch 65/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8717 - loss: 0.3508
# Epoch 66/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8539 - loss: 0.7972
# Epoch 67/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6803 - loss: 0.9898
# Epoch 68/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6221 - loss: 1.0352
# Epoch 69/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6420 - loss: 0.7863
# Epoch 70/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7320 - loss: 0.7088
# Epoch 71/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6495 - loss: 0.7290
# Epoch 72/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6531 - loss: 0.7335
# Epoch 73/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6605 - loss: 0.7106
# Epoch 74/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6619 - loss: 0.7405
# Epoch 75/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6729 - loss: 0.6715
# Epoch 76/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6980 - loss: 0.6589
# Epoch 77/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7273 - loss: 0.6419
# Epoch 78/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7258 - loss: 0.6234
# Epoch 79/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7076 - loss: 0.6209
# Epoch 80/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7190 - loss: 0.6001
# Epoch 81/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7443 - loss: 0.5916
# Epoch 82/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7447 - loss: 0.5721
# Epoch 83/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7491 - loss: 0.5701
# Epoch 84/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7106 - loss: 0.6062
# Epoch 85/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7492 - loss: 0.5615
# Epoch 86/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7327 - loss: 0.5803
# Epoch 87/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7455 - loss: 0.5668
# Epoch 88/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7676 - loss: 0.5495
# Epoch 89/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7847 - loss: 0.5280
# Epoch 90/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7770 - loss: 0.5203
# Epoch 91/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7886 - loss: 0.5045
# Epoch 92/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7986 - loss: 0.4842
# Epoch 93/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7945 - loss: 0.4776
# Epoch 94/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8119 - loss: 0.4554
# Epoch 95/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7936 - loss: 0.4891
# Epoch 96/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8135 - loss: 0.4615
# Epoch 97/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8091 - loss: 0.4558
# Epoch 98/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7890 - loss: 0.7500
# Epoch 99/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7868 - loss: 0.4906
# Epoch 100/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8112 - loss: 0.4633
# Epoch 101/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8119 - loss: 0.4548
# Epoch 102/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7829 - loss: 0.5094
# Epoch 103/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8089 - loss: 0.4682
# Epoch 104/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8224 - loss: 0.4395
# Epoch 105/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8129 - loss: 0.4548
# Epoch 106/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8215 - loss: 0.4274
# Epoch 107/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8328 - loss: 0.4163
# Epoch 108/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8315 - loss: 0.4092
# Epoch 109/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8328 - loss: 0.3994
# Epoch 110/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8428 - loss: 0.3836
# Epoch 111/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8466 - loss: 0.3811
# Epoch 112/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8492 - loss: 0.3692
# Epoch 113/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8564 - loss: 0.3614
# Epoch 114/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8504 - loss: 0.3703
# Epoch 115/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8585 - loss: 0.3559
# Epoch 116/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8583 - loss: 0.3522
# Epoch 117/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8615 - loss: 0.3468
# Epoch 118/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8639 - loss: 0.3438
# Epoch 119/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8663 - loss: 0.3404
# Epoch 120/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8697 - loss: 0.3288
# Epoch 121/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8749 - loss: 0.3191
# Epoch 122/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8780 - loss: 0.3126
# Epoch 123/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8778 - loss: 0.3132
# Epoch 124/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8730 - loss: 0.3225
# Epoch 125/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8658 - loss: 0.3418
# Epoch 126/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8709 - loss: 0.3220
# Epoch 127/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8777 - loss: 0.3109
# Epoch 128/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8840 - loss: 0.2954
# Epoch 129/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8853 - loss: 0.2940
# Epoch 130/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8854 - loss: 0.2907
# Epoch 131/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8810 - loss: 0.3100
# Epoch 132/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8786 - loss: 0.3057
# Epoch 133/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8813 - loss: 0.3085
# Epoch 134/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8821 - loss: 0.3028
# Epoch 135/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8850 - loss: 0.2906
# Epoch 136/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8903 - loss: 0.2794
# Epoch 137/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8850 - loss: 0.3109
# Epoch 138/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8526 - loss: 0.3934
# Epoch 139/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8605 - loss: 0.3466
# Epoch 140/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8859 - loss: 0.2961
# Epoch 141/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8904 - loss: 0.2898
# Epoch 142/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8936 - loss: 0.2842
# Epoch 143/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8941 - loss: 0.2815
# Epoch 144/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8997 - loss: 0.2647
# Epoch 145/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9022 - loss: 0.2586
# Epoch 146/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9041 - loss: 0.2556
# Epoch 147/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9065 - loss: 0.2422
# Epoch 148/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9034 - loss: 0.2497
# Epoch 149/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9060 - loss: 0.2402
# Epoch 150/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9080 - loss: 0.2373
# Epoch 151/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9097 - loss: 0.2353
# Epoch 152/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9093 - loss: 0.2408
# Epoch 153/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8979 - loss: 0.2663
# Epoch 154/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9027 - loss: 0.2639
# Epoch 155/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8910 - loss: 0.2839
# Epoch 156/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8238 - loss: 0.5355
# Epoch 157/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6889 - loss: 0.8505
# Epoch 158/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7404 - loss: 0.5966
# Epoch 159/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7601 - loss: 0.5465
# Epoch 160/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8064 - loss: 0.4510
# Epoch 161/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8193 - loss: 0.4372
# Epoch 162/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8106 - loss: 0.4446
# Epoch 163/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8283 - loss: 0.4208
# Epoch 164/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8422 - loss: 0.3965
# Epoch 165/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8457 - loss: 0.3813
# Epoch 166/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8550 - loss: 0.3663
# Epoch 167/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8620 - loss: 0.3520
# Epoch 168/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8660 - loss: 0.3403
# Epoch 169/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8746 - loss: 0.3256
# Epoch 170/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8791 - loss: 0.3207
# Epoch 171/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8849 - loss: 0.3107
# Epoch 172/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8880 - loss: 0.3015
# Epoch 173/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8812 - loss: 0.3518
# Epoch 174/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8880 - loss: 0.2966
# Epoch 175/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8851 - loss: 0.3051
# Epoch 176/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8898 - loss: 0.2955
# Epoch 177/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8923 - loss: 0.2885
# Epoch 178/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8974 - loss: 0.2770
# Epoch 179/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8996 - loss: 0.2714
# Epoch 180/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8933 - loss: 0.2834
# Epoch 181/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9014 - loss: 0.2629
# Epoch 182/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9017 - loss: 0.2631
# Epoch 183/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9002 - loss: 0.2610
# Epoch 184/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9063 - loss: 0.2506
# Epoch 185/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8984 - loss: 0.2686
# Epoch 186/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9071 - loss: 0.2488
# Epoch 187/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9044 - loss: 0.2571
# Epoch 188/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9058 - loss: 0.2470
# Epoch 189/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9098 - loss: 0.2417
# Epoch 190/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9070 - loss: 0.2452
# Epoch 191/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9103 - loss: 0.2371
# Epoch 192/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9111 - loss: 0.2385
# Epoch 193/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9101 - loss: 0.2368
# Epoch 194/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9105 - loss: 0.2366
# Epoch 195/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9135 - loss: 0.2269
# Epoch 196/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9146 - loss: 0.2253
# Epoch 197/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9139 - loss: 0.2244
# Epoch 198/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9170 - loss: 0.2206
# Epoch 199/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9167 - loss: 0.2202
# Epoch 200/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9179 - loss: 0.2158

# %%
plt.plot(model_history.history["accuracy"])

# %%
CLASS_COLORS = np.array([
    [0, 0, 0],        # background = black
    [0, 255, 0],      # good = green
    [255, 255, 0],    # fair = yellow
    [255, 0, 0]       # poor = red
], dtype=np.uint8)

def mask_to_color(mask):
    """
    Convert integer mask (0,1,2,3) to RGB color mask
    """
    mask = mask.numpy() if tf.is_tensor(mask) else mask  # convert TF tensor to NumPy
    color_mask = CLASS_COLORS[mask.astype(np.int32)]
    return color_mask

def display(display_list):
    """
    display_list = [input_image, true_mask, predicted_mask]
    """
    plt.figure(figsize=(15, 15))
    titles = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i + 1)
        plt.axis('off')
        plt.title(titles[i])

        if i == 1 or i == 2:  # True mask or predicted mask
            mask = display_list[i]
            if mask.shape[-1] == 1:  # single channel
                mask = mask[..., 0]
            color_mask = mask_to_color(mask)
            plt.imshow(color_mask)
        else:
            plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))

    plt.show()

def create_mask(pred_mask):
    """
    Converts UNet softmax output to integer mask (0,1,2,3)
    """
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0].numpy().astype(np.uint8)

def show_predictions(dataset=None, num=1):
    """
    Displays predictions for the first 'num' batches of a dataset
    """
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = unet.predict(image)
            display([image[0], mask[0], create_mask(pred_mask)])
    else:
        pred_mask = unet.predict(sample_image[tf.newaxis, ...])
        display([sample_image, sample_mask, create_mask(pred_mask)])

# %%
print("----- training_dataset results---------")
show_predictions(train_dataset, 6)
print("----- validation_dataset results---------")
show_predictions(validation_dataset, 6)
# Out:
# ----- training_dataset results---------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ----- validation_dataset results---------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %%
# model evaluation
print("Unet Model Evaluation: ")
unet.evaluate(validation_dataset)
# Out:
# Unet Model Evaluation:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8832 - loss: 0.3549
# [0.35486453771591187, 0.8832194209098816]
