# %%
# !sudo nvidia-smi
# Out:
# Wed Nov 12 22:18:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.05              Driver Version: 580.95.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Quadro RTX 4000                Off |   00000000:18:00.0 Off |                  N/A |
# | 30%   34C    P8              9W /  125W |       9MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Quadro RTX 4000                Off |   00000000:3B:00.0 Off |                  N/A |
# | 30%   40C    P8             16W /  125W |     228MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)

# List GPUs available
gpus = tf.config.list_physical_devices('GPU')
print("GPUs:", gpus)

# Check if GPUs are available
if gpus:
    print("GPU is available.")
else:
    print("GPU is not available.")

# Set memory growth for each GPU
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 2025-11-12 22:18:27.974560: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-12 22:18:28.028382: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-12 22:18:29.305792: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# TensorFlow version: 2.20.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# GPU is available.

# %%
# !pip install matplotlib
# !pip install scikit-learn

# %%
# !pip install patchify

# %%
# !pip install Pillow

# %%
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"

import segmentation_models as sm
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
from keras_unet.models import custom_unet

model = custom_unet(
    input_shape=(128,128,3),
    num_classes=1,
    use_batch_norm=True,
    dropout=0.5,
)
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762985911.419931   89846 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6631 MB memory:  -> device: 0, name: Quadro RTX 4000, pci bus id: 0000:18:00.0, compute capability: 7.5
# I0000 00:00:1762985911.421643   89846 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 6378 MB memory:  -> device: 1, name: Quadro RTX 4000, pci bus id: 0000:3b:00.0, compute capability: 7.5

# %%
import os
import cv2
import numpy as np

from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
import segmentation_models as sm
from tensorflow.keras.metrics import MeanIoU

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
scaler = MinMaxScaler()

# %%
# root_directory = r".\inputUsers\Januka\Downloads\Compressed\Semantic segmentation dataset"
root_directory = "./data_set/"
patch_size = 256

# %%
image_dataset = []

for path, subdirs, files in os.walk(root_directory):
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'images':
        images = sorted([f for f in os.listdir(path) if f.endswith('.jpg')])  # SORTED
        for image_name in images:
            image = cv2.imread(os.path.join(path, image_name), 1)  # Read as BGR
            SIZE_X = (image.shape[1]//patch_size)*patch_size
            SIZE_Y = (image.shape[0]//patch_size)*patch_size
            image = Image.fromarray(image)
            image = image.crop((0, 0, SIZE_X, SIZE_Y))
            image = np.array(image)

            print("Now patchifying image:", os.path.join(path, image_name))
            patches_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)

            for ii in range(patches_img.shape[0]):
                for jj in range(patches_img.shape[1]):
                    single_patch_img = patches_img[ii, jj, :, :]
                    single_patch_img = scaler.fit_transform(single_patch_img.reshape(-1, single_patch_img.shape[-1])).reshape(single_patch_img.shape)
                    single_patch_img = single_patch_img[0]  # Drop extra dimension
                    image_dataset.append(single_patch_img)
# Out:
# Now patchifying image: ./data_set/Tile 2/images/image_part_001.jpg
# Now patchifying image: ./data_set/Tile 2/images/image_part_002.jpg
# Now patchifying image: ./data_set/Tile 2/images/image_part_003.jpg
# Now patchifying image: ./data_set/Tile 2/images/image_part_004.jpg
# Now patchifying image: ./data_set/Tile 2/images/image_part_005.jpg
# Now patchifying image: ./data_set/Tile 2/images/image_part_006.jpg
# Now patchifying image: ./data_set/Tile 2/images/image_part_007.jpg
# Now patchifying image: ./data_set/Tile 2/images/image_part_008.jpg
# Now patchifying image: ./data_set/Tile 2/images/image_part_009.jpg
# Now patchifying image: ./data_set/Tile 8/images/image_part_001.jpg
# Now patchifying image: ./data_set/Tile 8/images/image_part_002.jpg
# Now patchifying image: ./data_set/Tile 8/images/image_part_003.jpg
# Now patchifying image: ./data_set/Tile 8/images/image_part_004.jpg
# Now patchifying image: ./data_set/Tile 8/images/image_part_005.jpg
# Now patchifying image: ./data_set/Tile 8/images/image_part_006.jpg
# Now patchifying image: ./data_set/Tile 8/images/image_part_007.jpg
# Now patchifying image: ./data_set/Tile 8/images/image_part_008.jpg
# Now patchifying image: ./data_set/Tile 8/images/image_part_009.jpg
# Now patchifying image: ./data_set/Tile 5/images/image_part_001.jpg
# Now patchifying image: ./data_set/Tile 5/images/image_part_002.jpg
# Now patchifying image: ./data_set/Tile 5/images/image_part_003.jpg
# Now patchifying image: ./data_set/Tile 5/images/image_part_004.jpg
# Now patchifying image: ./data_set/Tile 5/images/image_part_005.jpg
# Now patchifying image: ./data_set/Tile 5/images/image_part_006.jpg
# Now patchifying image: ./data_set/Tile 5/images/image_part_007.jpg
# Now patchifying image: ./data_set/Tile 5/images/image_part_008.jpg
# Now patchifying image: ./data_set/Tile 5/images/image_part_009.jpg
# Now patchifying image: ./data_set/Tile 1/images/image_part_001.jpg
# Now patchifying image: ./data_set/Tile 1/images/image_part_002.jpg
# Now patchifying image: ./data_set/Tile 1/images/image_part_003.jpg
# Now patchifying image: ./data_set/Tile 1/images/image_part_004.jpg
# Now patchifying image: ./data_set/Tile 1/images/image_part_005.jpg
# Now patchifying image: ./data_set/Tile 1/images/image_part_006.jpg
# Now patchifying image: ./data_set/Tile 1/images/image_part_007.jpg
# Now patchifying image: ./data_set/Tile 1/images/image_part_008.jpg
# Now patchifying image: ./data_set/Tile 1/images/image_part_009.jpg
# Now patchifying image: ./data_set/Tile 6/images/image_part_001.jpg
# Now patchifying image: ./data_set/Tile 6/images/image_part_002.jpg
# Now patchifying image: ./data_set/Tile 6/images/image_part_003.jpg
# Now patchifying image: ./data_set/Tile 6/images/image_part_004.jpg
# Now patchifying image: ./data_set/Tile 6/images/image_part_005.jpg
# Now patchifying image: ./data_set/Tile 6/images/image_part_006.jpg
# Now patchifying image: ./data_set/Tile 6/images/image_part_007.jpg
# Now patchifying image: ./data_set/Tile 6/images/image_part_008.jpg
# Now patchifying image: ./data_set/Tile 6/images/image_part_009.jpg
# Now patchifying image: ./data_set/Tile 4/images/image_part_001.jpg
# Now patchifying image: ./data_set/Tile 4/images/image_part_002.jpg
# Now patchifying image: ./data_set/Tile 4/images/image_part_003.jpg
# Now patchifying image: ./data_set/Tile 4/images/image_part_004.jpg
# Now patchifying image: ./data_set/Tile 4/images/image_part_005.jpg
# Now patchifying image: ./data_set/Tile 4/images/image_part_006.jpg
# Now patchifying image: ./data_set/Tile 4/images/image_part_007.jpg
# Now patchifying image: ./data_set/Tile 4/images/image_part_008.jpg
# Now patchifying image: ./data_set/Tile 4/images/image_part_009.jpg
# Now patchifying image: ./data_set/Tile 3/images/image_part_001.jpg
# Now patchifying image: ./data_set/Tile 3/images/image_part_002.jpg
# Now patchifying image: ./data_set/Tile 3/images/image_part_003.jpg
# Now patchifying image: ./data_set/Tile 3/images/image_part_004.jpg
# Now patchifying image: ./data_set/Tile 3/images/image_part_005.jpg
# Now patchifying image: ./data_set/Tile 3/images/image_part_006.jpg
# Now patchifying image: ./data_set/Tile 3/images/image_part_007.jpg
# Now patchifying image: ./data_set/Tile 3/images/image_part_008.jpg
# Now patchifying image: ./data_set/Tile 3/images/image_part_009.jpg
# Now patchifying image: ./data_set/Tile 7/images/image_part_001.jpg
# Now patchifying image: ./data_set/Tile 7/images/image_part_002.jpg
# Now patchifying image: ./data_set/Tile 7/images/image_part_003.jpg
# Now patchifying image: ./data_set/Tile 7/images/image_part_004.jpg
# Now patchifying image: ./data_set/Tile 7/images/image_part_005.jpg
# Now patchifying image: ./data_set/Tile 7/images/image_part_006.jpg
# Now patchifying image: ./data_set/Tile 7/images/image_part_007.jpg
# Now patchifying image: ./data_set/Tile 7/images/image_part_008.jpg
# Now patchifying image: ./data_set/Tile 7/images/image_part_009.jpg

# %%
mask_dataset = []

for path, subdirs, files in os.walk(root_directory):
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'masks':
        masks = sorted([f for f in os.listdir(path) if f.endswith('.png')])  # SORTED
        for mask_name in masks:
            mask = cv2.imread(os.path.join(path, mask_name), 1)
            mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
            SIZE_X = (mask.shape[1]//patch_size)*patch_size
            SIZE_Y = (mask.shape[0]//patch_size)*patch_size
            mask = Image.fromarray(mask)
            mask = mask.crop((0, 0, SIZE_X, SIZE_Y))
            mask = np.array(mask)

            print("Now patchifying mask:", os.path.join(path, mask_name))
            patches_mask = patchify(mask, (patch_size, patch_size, 3), step=patch_size)

            for ii in range(patches_mask.shape[0]):
                for jj in range(patches_mask.shape[1]):
                    single_patch_mask = patches_mask[ii, jj, :, :]
                    single_patch_mask = single_patch_mask[0]  # Drop extra dimension
                    mask_dataset.append(single_patch_mask)
# Out:
# Now patchifying mask: ./data_set/Tile 2/masks/image_part_001.png
# Now patchifying mask: ./data_set/Tile 2/masks/image_part_002.png
# Now patchifying mask: ./data_set/Tile 2/masks/image_part_003.png
# Now patchifying mask: ./data_set/Tile 2/masks/image_part_004.png
# Now patchifying mask: ./data_set/Tile 2/masks/image_part_005.png
# Now patchifying mask: ./data_set/Tile 2/masks/image_part_006.png
# Now patchifying mask: ./data_set/Tile 2/masks/image_part_007.png
# Now patchifying mask: ./data_set/Tile 2/masks/image_part_008.png
# Now patchifying mask: ./data_set/Tile 2/masks/image_part_009.png
# Now patchifying mask: ./data_set/Tile 8/masks/image_part_001.png
# Now patchifying mask: ./data_set/Tile 8/masks/image_part_002.png
# Now patchifying mask: ./data_set/Tile 8/masks/image_part_003.png
# Now patchifying mask: ./data_set/Tile 8/masks/image_part_004.png
# Now patchifying mask: ./data_set/Tile 8/masks/image_part_005.png
# Now patchifying mask: ./data_set/Tile 8/masks/image_part_006.png
# Now patchifying mask: ./data_set/Tile 8/masks/image_part_007.png
# Now patchifying mask: ./data_set/Tile 8/masks/image_part_008.png
# Now patchifying mask: ./data_set/Tile 8/masks/image_part_009.png
# Now patchifying mask: ./data_set/Tile 5/masks/image_part_001.png
# Now patchifying mask: ./data_set/Tile 5/masks/image_part_002.png
# Now patchifying mask: ./data_set/Tile 5/masks/image_part_003.png
# Now patchifying mask: ./data_set/Tile 7/masks/image_part_003.png
# Now patchifying mask: ./data_set/Tile 7/masks/image_part_004.png
# Now patchifying mask: ./data_set/Tile 7/masks/image_part_005.png
# Now patchifying mask: ./data_set/Tile 7/masks/image_part_006.png
# Now patchifying mask: ./data_set/Tile 7/masks/image_part_007.png
# Now patchifying mask: ./data_set/Tile 7/masks/image_part_008.png
# Now patchifying mask: ./data_set/Tile 7/masks/image_part_009.png

# %%
image_dataset = np.array(image_dataset)
mask_dataset =  np.array(mask_dataset)

# %%
#Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(image_dataset[image_number], (patch_size, patch_size, 3)))
plt.subplot(122)
plt.imshow(np.reshape(mask_dataset[image_number], (patch_size, patch_size, 3)))
plt.show()

# %%
"""
RGB to HEX: (Hexadecimel --> base 16)
This number divided by sixteen (integer division; ignoring any remainder) gives
the first hexadecimal digit (between 0 and F, where the letters A to F represent
the numbers 10 to 15). The remainder gives the second hexadecimal digit.
0-9 --> 0-9
10-15 --> A-F

Example: RGB --> R=201, G=, B=

R = 201/16 = 12 with remainder of 9. So hex code for R is C9 (remember C=12)

Calculating RGB from HEX: #3C1098
3C = 3*16 + 12 = 60
10 = 1*16 + 0 = 16
98 = 9*16 + 8 = 152

"""
# Out:
# '\nRGB to HEX: (Hexadecimel --> base 16)\nThis number divided by sixteen (integer division; ignoring any remainder) gives\nthe first hexadecimal digit (between 0 and F, where the letters A to F represent\nthe numbers 10 to 15). The remainder gives the second hexadecimal digit.\n0-9 --> 0-9\n10-15 --> A-F\n\nExample: RGB --> R=201, G=, B=\n\nR = 201/16 = 12 with remainder of 9. So hex code for R is C9 (remember C=12)\n\nCalculating RGB from HEX: #3C1098\n3C = 3*16 + 12 = 60\n10 = 1*16 + 0 = 16\n98 = 9*16 + 8 = 152\n\n'

# %%
#Convert HEX to RGB array
# Try the following to understand how python handles hex values...
a=int('3C', 16)  #3C with base 16. Should return 60.
print(a)
#Do the same for all RGB channels in each hex code to convert to RGB
Building = '#3C1098'.lstrip('#')
Building = np.array(tuple(int(Building[i:i+2], 16) for i in (0, 2, 4))) # 60, 16, 152

Land = '#8429F6'.lstrip('#')
Land = np.array(tuple(int(Land[i:i+2], 16) for i in (0, 2, 4))) #132, 41, 246

Road = '#6EC1E4'.lstrip('#')
Road = np.array(tuple(int(Road[i:i+2], 16) for i in (0, 2, 4))) #110, 193, 228

Vegetation =  'FEDD3A'.lstrip('#')
Vegetation = np.array(tuple(int(Vegetation[i:i+2], 16) for i in (0, 2, 4))) #254, 221, 58

Water = 'E2A929'.lstrip('#')
Water = np.array(tuple(int(Water[i:i+2], 16) for i in (0, 2, 4))) #226, 169, 41

Unlabeled = '#9B9B9B'.lstrip('#')
Unlabeled = np.array(tuple(int(Unlabeled[i:i+2], 16) for i in (0, 2, 4))) #155, 155, 155

label = single_patch_mask
# Out:
# 60

# %%
# Now replace RGB to integer values to be used as labels.
#Find pixels with combination of RGB for the above defined arrays...
#if matches then replace all values in that pixel with a specific integer
def rgb_to_2D_label(label):
    """
    Suply our labale masks as input in RGB format.
    Replace pixels with specific RGB values ...
    """
    label_seg = np.zeros(label.shape,dtype=np.uint8)
    label_seg [np.all(label == Building,axis=-1)] = 0
    label_seg [np.all(label==Land,axis=-1)] = 1
    label_seg [np.all(label==Road,axis=-1)] = 2
    label_seg [np.all(label==Vegetation,axis=-1)] = 3
    label_seg [np.all(label==Water,axis=-1)] = 4
    label_seg [np.all(label==Unlabeled,axis=-1)] = 5

    label_seg = label_seg[:,:,0]  #Just take the first channel, no need for all 3 channels

    return label_seg

# %%
labels = []
for i in range(mask_dataset.shape[0]):
    label = rgb_to_2D_label(mask_dataset[i])
    labels.append(label)

labels = np.array(labels)
labels = np.expand_dims(labels, axis=3)


print("Unique labels in label dataset are: ", np.unique(labels))

#Another Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(image_dataset))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(image_dataset[image_number])
plt.subplot(122)
plt.imshow(labels[image_number][:,:,0])
plt.show()
# Out:
# Unique labels in label dataset are:  [0 1 2 3 4 5]

# %%
n_classes = len(np.unique(labels))
from keras.utils import to_categorical
labels_cat = to_categorical(labels, num_classes=n_classes)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, labels_cat, test_size = 0.20, random_state = 42)

# %%
#Parameters for model
# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
# set class weights for dice_loss
# from sklearn.utils.class_weight import compute_class_weight

# weights = compute_class_weight('balanced', np.unique(np.ravel(labels,order='C')),
#                               np.ravel(labels,order='C'))
# print(weights)

# %%
weights = [0.1666, 0.1666, 0.1666, 0.1666, 0.1666, 0.1666]
dice_loss = sm.losses.DiceLoss(class_weights=weights)
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)  #

# %%
IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras import backend as K

# %%
#original code
# def jacard_coef(y_true, y_pred):
#     y_true_f = K.flatten(y_true)
#     y_pred_f = K.flatten(y_pred)
#     intersection = K.sum(y_true_f * y_pred_f)
#     return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# %%
def jacard_coef(y_true, y_pred, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    
    return (intersection + smooth) / (union + smooth)

# %%
def multi_unet_model(n_classes=4, IMG_HEIGHT=256, IMG_WIDTH=256, IMG_CHANNELS=1):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.2)(c1)  # Original 0.1
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.2)(c2)  # Original 0.1
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    #Expansive path
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.2)(c8)  # Original 0.1
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.2)(c9)  # Original 0.1
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)

    model = Model(inputs=[inputs], outputs=[outputs])

    return model

# %%
metrics=['accuracy', jacard_coef]

# %%
def get_model():
    return multi_unet_model(n_classes=6, IMG_HEIGHT=256, IMG_WIDTH=256, IMG_CHANNELS=3)

# %%
from keras import backend as K
K.clear_session()

# %%
model = get_model()
model.compile(optimizer='adam', loss=total_loss, metrics=metrics)
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=metrics)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256, 256,  │          0 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      2,320 │ dropout[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      9,248 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │     36,928 │ dropout_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    147,584 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │    295,168 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_8[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │    590,080 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    131,200 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │    295,040 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    147,584 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │     32,832 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │     73,792 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │     36,928 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │      8,224 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     18,464 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │      9,248 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      2,064 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │      4,624 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 256, 256,  │          0 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      2,320 │ dropout_8[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │        102 │ conv2d_17[0][0]   │
# │                     │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,941,190 (7.41 MB)
#  Trainable params: 1,941,190 (7.41 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (1044, 256, 256, 3) (1044, 256, 256, 6)

# %%
X_train = X_train.astype('float16')
y_train = y_train.astype('float16')
X_test = X_test.astype('float16')
y_test = y_test.astype('float16')

# %%
def data_generator(X, y, batch_size=8):
    total_samples = X.shape[0]
    indices = np.arange(total_samples)
    while True:
        np.random.shuffle(indices)
        for start in range(0, total_samples, batch_size):
            end = min(start + batch_size, total_samples)
            batch_indices = indices[start:end]
            yield X[batch_indices], y[batch_indices]

train_gen = data_generator(X_train, y_train, batch_size=4)
test_gen = data_generator(X_test, y_test, batch_size=4)

# %%
history1 = model.fit(train_gen,
                     steps_per_epoch=len(X_train) // 4,  # Adjusted to new batch size
                     verbose=1,
                     epochs=100,
                     validation_data=test_gen,
                     validation_steps=len(X_test) // 4,
                     shuffle=False)
# Out:
# Epoch 1/100
# 2025-11-12 22:19:10.071834: E tensorflow/core/util/util.cc:131] oneDNN supports DT_HALF only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 2025-11-12 22:19:10.131131: I external/local_xla/xla/service/service.cc:163] XLA service 0x70997c016c40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-12 22:19:10.131164: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0):
100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8573 - jacard_coef: 0.7026 - loss: 0.9177 - val_accuracy: 0.8387 - val_jacard_coef: 0.6754 - val_loss: 0.9219
# Epoch 27/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8560 - jacard_coef: 0.7028 - loss: 0.9172 - val_accuracy: 0.8463 - val_jacard_coef: 0.7006 - val_loss: 0.9245
# Epoch 28/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8596 - jacard_coef: 0.7098 - loss: 0.9147 - val_accuracy: 0.8336 - val_jacard_coef: 0.6710 - val_loss: 0.9252
# Epoch 29/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8567 - jacard_coef: 0.7059 - loss: 0.9181 - val_accuracy: 0.8328 - val_jacard_coef: 0.6791 - val_loss: 0.9295
# Epoch 30/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8579 - jacard_coef: 0.7070 - loss: 0.9163 - val_accuracy: 0.8388 - val_jacard_coef: 0.6915 - val_loss: 0.9242
# Epoch 31/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8584 - jacard_coef: 0.7083 - loss: 0.9166 - val_accuracy: 0.8435 - val_jacard_coef: 0.6977 - val_loss: 0.9227
# Epoch 32/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8571 - jacard_coef: 0.7057 - loss: 0.9163 - val_accuracy: 0.8315 - val_jacard_coef: 0.6743 - val_loss: 0.9275
# Epoch 33/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8606 - jacard_coef: 0.7146 - loss: 0.9157 - val_accuracy: 0.8415 - val_jacard_coef: 0.6781 - val_loss: 0.9226
# Epoch 34/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8627 - jacard_coef: 0.7171 - loss: 0.9144 - val_accuracy: 0.8319 - val_jacard_coef: 0.6825 - val_loss: 0.9240
# Epoch 35/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8661 - jacard_coef: 0.7236 - loss: 0.9124 - val_accuracy: 0.8407 - val_jacard_coef: 0.6933 - val_loss: 0.9240
# Epoch 36/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8657 - jacard_coef: 0.7240 - loss: 0.9137 - val_accuracy: 0.8485 - val_jacard_coef: 0.7154 - val_loss: 0.9239
# Epoch 37/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8651 - jacard_coef: 0.7234 - loss: 0.9121 - val_accuracy: 0.8405 - val_jacard_coef: 0.6934 - val_loss: 0.9251
# Epoch 38/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8657 - jacard_coef: 0.7248 - loss: 0.9130 - val_accuracy: 0.8340 - val_jacard_coef: 0.6879 - val_loss: 0.9249
# Epoch 39/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8700 - jacard_coef: 0.7315 - loss: 0.9119 - val_accuracy: 0.8373 - val_jacard_coef: 0.6949 - val_loss: 0.9218
# Epoch 40/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8701 - jacard_coef: 0.7351 - loss: 0.9114 - val_accuracy: 0.8291 - val_jacard_coef: 0.6906 - val_loss: 0.9286
# Epoch 41/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8656 - jacard_coef: 0.7267 - loss: 0.9113 - val_accuracy: 0.8456 - val_jacard_coef: 0.7018 - val_loss: 0.9214
# Epoch 42/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8749 - jacard_coef: 0.7418 - loss: 0.9102 - val_accuracy: 0.8333 - val_jacard_coef: 0.6878 - val_loss: 0.9225
# Epoch 43/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8699 - jacard_coef: 0.7339 - loss: 0.9118 - val_accuracy: 0.8341 - val_jacard_coef: 0.6777 - val_loss: 0.9237
# Epoch 44/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8667 - jacard_coef: 0.7263 - loss: 0.9127 - val_accuracy: 0.8466 - val_jacard_coef: 0.7071 - val_loss: 0.9210
# Epoch 45/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8747 - jacard_coef: 0.7431 - loss: 0.9096 - val_accuracy: 0.8376 - val_jacard_coef: 0.6938 - val_loss: 0.9266
# Epoch 46/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8746 - jacard_coef: 0.7416 - loss: 0.9094 - val_accuracy: 0.8440 - val_jacard_coef: 0.6979 - val_loss: 0.9175
# Epoch 47/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8684 - jacard_coef: 0.7334 - loss: 0.9111 - val_accuracy: 0.8546 - val_jacard_coef: 0.7209 - val_loss: 0.9237
# Epoch 48/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8704 - jacard_coef: 0.7342 - loss: 0.9122 - val_accuracy: 0.8438 - val_jacard_coef: 0.7069 - val_loss: 0.9229
# Epoch 49/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8758 - jacard_coef: 0.7448 - loss: 0.9090 - val_accuracy: 0.8304 - val_jacard_coef: 0.6784 - val_loss: 0.9233
# Epoch 50/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8804 - jacard_coef: 0.7531 - loss: 0.9066 - val_accuracy: 0.8585 - val_jacard_coef: 0.7194 - val_loss: 0.9202
# Epoch 51/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8751 - jacard_coef: 0.7437 - loss: 0.9101 - val_accuracy: 0.8522 - val_jacard_coef: 0.7191 - val_loss: 0.9253
# Epoch 52/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8816 - jacard_coef: 0.7560 - loss: 0.9075 - val_accuracy: 0.8424 - val_jacard_coef: 0.6908 - val_loss: 0.9212
# Epoch 53/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8798 - jacard_coef: 0.7509 - loss: 0.9072 - val_accuracy: 0.8475 - val_jacard_coef: 0.7149 - val_loss: 0.9252
# Epoch 54/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8800 - jacard_coef: 0.7526 - loss: 0.9064 - val_accuracy: 0.8496 - val_jacard_coef: 0.7068 - val_loss: 0.9237
# Epoch 55/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8795 - jacard_coef: 0.7517 - loss: 0.9081 - val_accuracy: 0.8437 - val_jacard_coef: 0.7013 - val_loss: 0.9231
# Epoch 56/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8801 - jacard_coef: 0.7523 - loss: 0.9071 - val_accuracy: 0.8460 - val_jacard_coef: 0.7103 - val_loss: 0.9203
# Epoch 57/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8836 - jacard_coef: 0.7585 - loss: 0.9070 - val_accuracy: 0.8615 - val_jacard_coef: 0.7306 - val_loss: 0.9218
# Epoch 58/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8837 - jacard_coef: 0.7585 - loss: 0.9065 - val_accuracy: 0.8422 - val_jacard_coef: 0.6953 - val_loss: 0.9270
# Epoch 59/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8807 - jacard_coef: 0.7547 - loss: 0.9073 - val_accuracy: 0.8404 - val_jacard_coef: 0.6796 - val_loss: 0.9298
# Epoch 60/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8790 - jacard_coef: 0.7509 - loss: 0.9075 - val_accuracy: 0.8547 - val_jacard_coef: 0.7180 - val_loss: 0.9216
# Epoch 61/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8837 - jacard_coef: 0.7592 - loss: 0.9057 - val_accuracy: 0.8375 - val_jacard_coef: 0.6902 - val_loss: 0.9255
# Epoch 62/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8871 - jacard_coef: 0.7653 - loss: 0.9040 - val_accuracy: 0.8512 - val_jacard_coef: 0.7175 - val_loss: 0.9207
# Epoch 63/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8783 - jacard_coef: 0.7489 - loss: 0.9080 - val_accuracy: 0.8493 - val_jacard_coef: 0.7078 - val_loss: 0.9221
# Epoch 64/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8831 - jacard_coef: 0.7594 - loss: 0.9058 - val_accuracy: 0.8586 - val_jacard_coef: 0.7259 - val_loss: 0.9228
# Epoch 65/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8880 - jacard_coef: 0.7670 - loss: 0.9040 - val_accuracy: 0.8506 - val_jacard_coef: 0.7123 - val_loss: 0.9215
# Epoch 66/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8900 - jacard_coef: 0.7707 - loss: 0.9031 - val_accuracy: 0.8546 - val_jacard_coef: 0.7219 - val_loss: 0.9234
# Epoch 67/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8864 - jacard_coef: 0.7641 - loss: 0.9041 - val_accuracy: 0.8569 - val_jacard_coef: 0.7244 - val_loss: 0.9201
# Epoch 68/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8925 - jacard_coef: 0.7748 - loss: 0.9020 - val_accuracy: 0.8555 - val_jacard_coef: 0.7177 - val_loss: 0.9222
# Epoch 69/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8904 - jacard_coef: 0.7719 - loss: 0.9024 - val_accuracy: 0.8528 - val_jacard_coef: 0.7160 - val_loss: 0.9243
# Epoch 70/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8909 - jacard_coef: 0.7733 - loss: 0.9029 - val_accuracy: 0.8537 - val_jacard_coef: 0.7112 - val_loss: 0.9254
# Epoch 71/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8920 - jacard_coef: 0.7752 - loss: 0.9022 - val_accuracy: 0.8548 - val_jacard_coef: 0.7200 - val_loss: 0.9204
# Epoch 72/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8780 - jacard_coef: 0.7485 - loss: 0.9098 - val_accuracy: 0.8521 - val_jacard_coef: 0.7208 - val_loss: 0.9214
# Epoch 73/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8913 - jacard_coef: 0.7742 - loss: 0.9034 - val_accuracy: 0.8537 - val_jacard_coef: 0.7169 - val_loss: 0.9217
# Epoch 74/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8929 - jacard_coef: 0.7766 - loss: 0.9034 - val_accuracy: 0.8478 - val_jacard_coef: 0.7123 - val_loss: 0.9247
# Epoch 75/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8917 - jacard_coef: 0.7738 - loss: 0.9022 - val_accuracy: 0.8593 - val_jacard_coef: 0.7329 - val_loss: 0.9214
# Epoch 76/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8840 - jacard_coef: 0.7602 - loss: 0.9061 - val_accuracy: 0.8519 - val_jacard_coef: 0.7161 - val_loss: 0.9221
# Epoch 77/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8924 - jacard_coef: 0.7753 - loss: 0.9024 - val_accuracy: 0.8493 - val_jacard_coef: 0.7179 - val_loss: 0.9245
# Epoch 78/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8976 - jacard_coef: 0.7851 - loss: 0.9019 - val_accuracy: 0.8629 - val_jacard_coef: 0.7354 - val_loss: 0.9234
# Epoch 79/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8944 - jacard_coef: 0.7800 - loss: 0.9009 - val_accuracy: 0.8459 - val_jacard_coef: 0.7112 - val_loss: 0.9226
# Epoch 80/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8936 - jacard_coef: 0.7782 - loss: 0.9013 - val_accuracy: 0.8379 - val_jacard_coef: 0.7016 - val_loss: 0.9271
# Epoch 81/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8952 - jacard_coef: 0.7804 - loss: 0.9007 - val_accuracy: 0.8480 - val_jacard_coef: 0.7028 - val_loss: 0.9258
# Epoch 82/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8940 - jacard_coef: 0.7784 - loss: 0.9011 - val_accuracy: 0.8518 - val_jacard_coef: 0.7199 - val_loss: 0.9228
# Epoch 83/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8969 - jacard_coef: 0.7834 - loss: 0.9010 - val_accuracy: 0.8570 - val_jacard_coef: 0.7312 - val_loss: 0.9232
# Epoch 84/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8912 - jacard_coef: 0.7723 - loss: 0.9037 - val_accuracy: 0.8585 - val_jacard_coef: 0.7347 - val_loss: 0.9218
# Epoch 85/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8976 - jacard_coef: 0.7858 - loss: 0.8995 - val_accuracy: 0.8534 - val_jacard_coef: 0.7132 - val_loss: 0.9260
# Epoch 86/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8946 - jacard_coef: 0.7795 - loss: 0.9022 - val_accuracy: 0.8666 - val_jacard_coef: 0.7452 - val_loss: 0.9171
# Epoch 87/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8963 - jacard_coef: 0.7823 - loss: 0.9018 - val_accuracy: 0.8504 - val_jacard_coef: 0.7155 - val_loss: 0.9222
# Epoch 88/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8986 - jacard_coef: 0.7868 - loss: 0.8993 - val_accuracy: 0.8480 - val_jacard_coef: 0.7107 - val_loss: 0.9219
# Epoch 89/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.8983 - jacard_coef: 0.7865 - loss: 0.9000 - val_accuracy: 0.8580 - val_jacard_coef: 0.7206 - val_loss: 0.9168
# Epoch 90/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8962 - jacard_coef: 0.7831 - loss: 0.9004 - val_accuracy: 0.8486 - val_jacard_coef: 0.7076 - val_loss: 0.9275
# Epoch 91/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8978 - jacard_coef: 0.7853 - loss: 0.9008 - val_accuracy: 0.8404 - val_jacard_coef: 0.7019 - val_loss: 0.9233
# Epoch 92/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8990 - jacard_coef: 0.7869 - loss: 0.8993 - val_accuracy: 0.8564 - val_jacard_coef: 0.7308 - val_loss: 0.9218
# Epoch 93/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9001 - jacard_coef: 0.7900 - loss: 0.8982 - val_accuracy: 0.8553 - val_jacard_coef: 0.7270 - val_loss: 0.9220
# Epoch 94/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8997 - jacard_coef: 0.7890 - loss: 0.8977 - val_accuracy: 0.8594 - val_jacard_coef: 0.7404 - val_loss: 0.9193
# Epoch 95/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8973 - jacard_coef: 0.7850 - loss: 0.9001 - val_accuracy: 0.8525 - val_jacard_coef: 0.7255 - val_loss: 0.9241
# Epoch 96/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.9016 - jacard_coef: 0.7922 - loss: 0.8980 - val_accuracy: 0.8680 - val_jacard_coef: 0.7488 - val_loss: 0.9182
# Epoch 97/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 35ms/step - accuracy: 0.9017 - jacard_coef: 0.7936 - loss: 0.8981 - val_accuracy: 0.8525 - val_jacard_coef: 0.7247 - val_loss: 0.9224
# Epoch 98/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8993 - jacard_coef: 0.7889 - loss: 0.8989 - val_accuracy: 0.8581 - val_jacard_coef: 0.7265 - val_loss: 0.9235
# Epoch 99/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8972 - jacard_coef: 0.7838 - loss: 0.9005 - val_accuracy: 0.8442 - val_jacard_coef: 0.7129 - val_loss: 0.9256
# Epoch 100/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - accuracy: 0.8877 - jacard_coef: 0.7681 - loss: 0.9041 - val_accuracy: 0.8422 - val_jacard_coef: 0.7074 - val_loss: 0.9283

# %%
model.save("./satellite_standard_unet_100epochs_12Nov2025.keras")

# %%
#plot the training and validation accuracy and loss at each epoch
history = history1
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['jacard_coef']
val_acc = history.history['val_jacard_coef']

plt.plot(epochs, acc, 'y', label='Training IoU')
plt.plot(epochs, val_acc, 'r', label='Validation IoU')
plt.title('Training and validation IoU')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()
