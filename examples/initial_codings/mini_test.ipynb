# %% [markdown]
# # 1. import the necessery libraries

# %%
# !sudo nvidia-smi
# Out:
# Thu Nov 20 19:37:53 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.05              Driver Version: 580.95.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Quadro RTX 4000                Off |   00000000:18:00.0 Off |                  N/A |
# | 30%   32C    P8              9W /  125W |    5911MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Quadro RTX 4000                Off |   00000000:3B:00.0 Off |                  N/A |
# | 30%   40C    P8             16W /  125W |     516MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           89846      C   ...hase02/venvs/tf220/bin/python       3954MiB |
# |    0   N/A  N/A          356968      C   ...hase02/venvs/tf220/bin/python        108MiB |
# |    0   N/A  N/A         1632877      C   ...hase02/venvs/tf220/bin/python       1840MiB |
# |    1   N/A  N/A           89846      C   ...hase02/venvs/tf220/bin/python         96MiB |
# |    1   N/A  N/A          356968      C   ...hase02/venvs/tf220/bin/python         96MiB |
# |    1   N/A  N/A         1632877      C   ...hase02/venvs/tf220/bin/python         96MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# If you want to use the spesific GPU
# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # use GPU 1 or GPU 0

import tensorflow as tf

# List GPUs available
gpus = tf.config.list_physical_devices('GPU')
print("GPUs:", gpus)

# Check if GPUs are available
if gpus:
    print("GPU is available.")
else:
    print("GPU is not available.")

# Set memory growth for each GPU
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 2025-11-20 19:37:57.268709: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-20 19:37:57.325667: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-20 19:37:58.616707: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# GPU is available.

# %%
import numpy as np
import os
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout 
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import concatenate
from tensorflow.keras import regularizers

# %% [markdown]
# # 2. load and split the data

# %%
import os 
import numpy as np 
import pandas as pd 
import imageio 
import matplotlib.pyplot as plt 

image_dir = "./data_set/images/"  # <-- use the real folder
mask_dir  = "./data_set/masks/"  # example

image_filenames = sorted([
    f for f in os.listdir(image_dir)
    if not f.startswith(".") and f.lower().endswith(".jpg")
])

mask_filenames = sorted([
    f for f in os.listdir(mask_dir)
    if not f.startswith(".") and f.lower().endswith(".png")
])

image_list = [os.path.join(image_dir, f) for f in image_filenames]
mask_list  = [os.path.join(mask_dir,  f) for f in mask_filenames]
train_image_list = image_list[:6]
train_mask_list = mask_list[:6]

validation_image_list = image_list[6:7]
validation_mask_list = mask_list[6:7]

print("image_list:", train_image_list)
print("mask_list:", train_mask_list)
# Out:
# image_list: ['./data_set/images/post-harvest_01.jpg', './data_set/images/post-harvest_01_2.jpg', './data_set/images/post-harvest_01_3.jpg', './data_set/images/post-harvest_02.jpg', './data_set/images/post-harvest_02_2.jpg', './data_set/images/post-harvest_03.jpg']
# mask_list: ['./data_set/masks/post-harvest_01.png', './data_set/masks/post-harvest_01_2.png', './data_set/masks/post-harvest_01_3.png', './data_set/masks/post-harvest_02.png', './data_set/masks/post-harvest_02_2.png', './data_set/masks/post-harvest_03.png']

# %% [markdown]
# # 3. explore some images :

# %%
n = 1 # you can chose any index 
img  = imageio.imread(train_image_list[n])
print(img.shape)
mask = imageio.imread(train_mask_list[n])
print(mask.shape)

# now let's plot 
fig ,arr  = plt.subplots(1,2,figsize=(15,10))
arr[0].imshow(img)
arr[0].set_title('Original Image')
arr[1].imshow(mask)
arr[1].set_title('Mask')
# Out:
# (312, 312, 3)
# (312, 312)
# /tmp/ipykernel_1950811/3232672074.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img  = imageio.imread(train_image_list[n])
# /tmp/ipykernel_1950811/3232672074.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mask = imageio.imread(train_mask_list[n])
# Text(0.5, 1.0, 'Mask')

# %%
train_images = tf.constant(train_image_list)
train_masks = tf.constant(train_mask_list)

train_dataset = tf.data.Dataset.from_tensor_slices((train_images,train_masks))
for image,mask in train_dataset.take(1) : 
    print(image)
    print(mask)
    
validation_images = tf.constant(validation_image_list)
validation_masks = tf.constant(validation_mask_list)

validation_dataset = tf.data.Dataset.from_tensor_slices((validation_images,validation_masks))
for image,mask in validation_dataset.take(1) : 
    print(image)
    print(mask)
# Out:
# tf.Tensor(b'./data_set/images/post-harvest_01.jpg', shape=(), dtype=string)
# tf.Tensor(b'./data_set/masks/post-harvest_01.png', shape=(), dtype=string)
# tf.Tensor(b'./data_set/images/post-harvest_03_2.jpg', shape=(), dtype=string)
# tf.Tensor(b'./data_set/masks/post-harvest_03_2.png', shape=(), dtype=string)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763667486.214060 1950811 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1554 MB memory:  -> device: 0, name: Quadro RTX 4000, pci bus id: 0000:18:00.0, compute capability: 7.5
# I0000 00:00:1763667486.215678 1950811 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 6090 MB memory:  -> device: 1, name: Quadro RTX 4000, pci bus id: 0000:3b:00.0, compute capability: 7.5
# 2025-11-20 19:38:06.292885: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-11-20 19:38:06.311743: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# # 4. preprocessing our data

# %%
def process_path(image_path,mask_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_png(img,channels=3)
    img = tf.image.convert_image_dtype(img,tf.float32) #this do the same as dividing by 255 to set the values between 0 and 1 (normalization)
    
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_png(mask,channels=3)
    mask = tf.math.reduce_max(mask,axis=-1,keepdims=True)
    return img , mask

def preprocess(image,mask) : 
    input_image = tf.image.resize(image,(96,128),method='nearest')
    input_mask = tf.image.resize(mask,(96,128),method='nearest')
    
    return input_image , input_mask

train_image_ds = train_dataset.map(process_path) # apply the preprocces_path function to our train_dataset
print(train_image_ds)
train_processed_image_ds = train_image_ds.map(preprocess) # apply the preprocess function to our train_dataset

validation_image_ds = validation_dataset.map(process_path) # apply the preprocces_path function to our validation_dataset
print(validation_image_ds)
validation_processed_image_ds = validation_image_ds.map(preprocess)
# Out:
# <_MapDataset element_spec=(TensorSpec(shape=(None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.uint8, name=None))>
# <_MapDataset element_spec=(TensorSpec(shape=(None, None, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.uint8, name=None))>

# %% [markdown]
# # Defining mean iou metric

# %%
NUM_CLASSES = 4

def mean_iou_metric(y_true, y_pred, smooth=1e-7):
    # y_true: (B, H, W) or (B, H, W, 1)
    # y_pred: (B, H, W, NUM_CLASSES) logits
    
    # Squeeze extra channel if exists
    if y_true.shape.rank == 4 and y_true.shape[-1] == 1:
        y_true = tf.squeeze(y_true, axis=-1)
    
    y_true = tf.cast(y_true, tf.int32)

    # Convert logits → class probabilities
    y_pred = tf.nn.softmax(y_pred, axis=-1)

    # Get predicted class ID
    y_pred_labels = tf.argmax(y_pred, axis=-1, output_type=tf.int32)

    # Compute IoU per class
    ious = []
    for c in range(NUM_CLASSES):
        y_true_c = tf.cast(tf.equal(y_true, c), tf.float32)
        y_pred_c = tf.cast(tf.equal(y_pred_labels, c), tf.float32)

        intersection = tf.reduce_sum(y_true_c * y_pred_c)
        union = tf.reduce_sum(y_true_c) + tf.reduce_sum(y_pred_c) - intersection

        iou = (intersection + smooth) / (union + smooth)
        ious.append(iou)

    # Return mean IoU over classes
    return tf.reduce_mean(tf.stack(ious))

# %% [markdown]
# # 5.  Define The Conv Block For The Contracting Path

# %%
def conv_block(inputs=None, n_filters=32, dropout_prob=0, max_pooling=True):
    
    conv = Conv2D(n_filters, 
                  kernel_size = 3,     
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(inputs)
    conv = Conv2D(n_filters, 
                  kernel_size = 3, 
                  activation='relu',
                  padding='same',
                  kernel_initializer=tf.keras.initializers.HeNormal())(conv)
   
    

    if dropout_prob > 0:
        conv = Dropout(dropout_prob)(conv)
        
    if max_pooling:
        next_layer = MaxPooling2D(pool_size=(2,2))(conv)
        
        
    else:
        next_layer = conv
        
    skip_connection = conv
    
    return next_layer, skip_connection

# %% [markdown]
# # 6. Define the upsampling block for the expanding path

# %%
def upsampling_block(expansive_input, contractive_input, n_filters=32):
    
    up = Conv2DTranspose(
                 n_filters,  
                 kernel_size = 3,
                 strides=(2,2),
                 padding='same')(expansive_input)
    
    merge = concatenate([up, contractive_input], axis=3)
    conv = Conv2D(n_filters,  
                 kernel_size = 3,   
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(merge)
    conv = Conv2D(n_filters,  
                 kernel_size = 3,  
                 activation='relu',
                 padding='same',
                 kernel_initializer=tf.keras.initializers.HeNormal())(conv)
    
    
    return conv

# %% [markdown]
# # 7. Finally! ,  we will Define the unet model
# ## which composes of a set of conv blocks and upsampling blocks

# %%
def unet_model(input_size=(96, 128, 3), n_filters=32, n_classes=23):
    
    inputs = Input(input_size)
    
    # contracting path
    cblock1 = conv_block(inputs, n_filters, dropout_prob=0.4)
    cblock2 = conv_block(cblock1[0], 2*n_filters, dropout_prob=0.4)
    cblock3 = conv_block(cblock2[0], 4*n_filters, dropout_prob=0.4)
    cblock4 = conv_block(cblock3[0], 8*n_filters, dropout_prob=0.45) 
    cblock5 = conv_block(cblock4[0],16*n_filters, dropout_prob=0.4, max_pooling=None)     
    
    # expanding path
    ublock6 = upsampling_block(cblock5[0], cblock4[1],  8 * n_filters)
    ublock7 = upsampling_block(ublock6, cblock3[1],  n_filters*4)
    ublock8 = upsampling_block(ublock7,cblock2[1] , n_filters*2)
    ublock9 = upsampling_block(ublock8,cblock1[1],  n_filters)

    conv9 = Conv2D(n_filters,
                 3,
                 activation='relu',
                 padding='same',
                 kernel_initializer='he_normal')(ublock9)
    
    conv10 = Conv2D(n_classes, kernel_size=1, padding='same')(conv9)  
    model = tf.keras.Model(inputs=inputs, outputs=conv10)

    return model

# %%
img_height = 96
img_width = 128
num_channels = 3

unet = unet_model((img_height, img_width, num_channels))

# %% [markdown]
# # 8. Our model is ready !!

# %%
unet.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 96, 128,   │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 96, 128,   │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 96, 128,   │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 96, 128,   │          0 │ conv2d_1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 48, 64,    │          0 │ dropout[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 48, 64,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 48, 64,    │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 48, 64,    │          0 │ conv2d_3[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 24, 32,    │          0 │ dropout_1[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 24, 32,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 24, 32,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 24, 32,    │          0 │ conv2d_5[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 12, 16,    │          0 │ dropout_2[0][0]   │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 12, 16,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 12, 16,    │    590,080 │ conv2d_6[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 12, 16,    │          0 │ conv2d_7[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 6, 8, 256) │          0 │ dropout_3[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 6, 8, 512) │  1,180,160 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 6, 8, 512) │  2,359,808 │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 6, 8, 512) │          0 │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 12, 16,    │  1,179,904 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 12, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 12, 16,    │  1,179,904 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 12, 16,    │    590,080 │ conv2d_10[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 24, 32,    │    295,040 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 24, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 24, 32,    │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 24, 32,    │    147,584 │ conv2d_12[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 48, 64,    │     73,792 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 48, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 48, 64,    │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 48, 64,    │     36,928 │ conv2d_14[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 96, 128,   │     18,464 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 96, 128,   │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 96, 128,   │     18,464 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 96, 128,   │      9,248 │ conv2d_16[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 96, 128,   │      9,248 │ conv2d_17[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 96, 128,   │        759 │ conv2d_18[0][0]   │
# │                     │ 23)               │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,640,471 (32.96 MB)
#  Trainable params: 8,640,471 (32.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
unet.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy', mean_iou_metric])

# %%
EPOCHS = 500
VAL_SUBSPLITS = 5
BUFFER_SIZE = 390
BATCH_SIZE = 2

# train
train_processed_image_ds.batch(BATCH_SIZE)
train_dataset = train_processed_image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
print(train_processed_image_ds.element_spec)

# validation
validation_processed_image_ds.batch(BATCH_SIZE)
validation_dataset = validation_processed_image_ds.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
print(validation_processed_image_ds.element_spec)
 

model_history = unet.fit(train_dataset, epochs=EPOCHS)
# Out:
# (TensorSpec(shape=(96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(96, 128, 1), dtype=tf.uint8, name=None))
# (TensorSpec(shape=(96, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(96, 128, 1), dtype=tf.uint8, name=None))
# Epoch 1/500
# 2025-11-20 19:38:16.337543: I external/local_xla/xla/service/service.cc:163] XLA service 0x7a320c003b60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-20 19:38:16.337575: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): Quadro RTX 4000, Compute Capability 7.5
# 2025-11-20 19:38:16.337582: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (1): Quadro RTX 4000, Compute Capability 7.5
# 2025-11-20 19:38:16.463530: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-20 19:38:16.804173: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-11-20 19:38:17.267697: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91500
# 2025-11-20 19:38:18.175596: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,64,24,32]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:38:18.222442: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,128,24,32]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:38:18.273939: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,128,12,16]{3,2,1,0}, f32[256,128,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:38:18.318990: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,256,12,16]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:38:18.367508: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,512,6,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,256,6,8]{3,2,1,0}, f32[512,256,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:38:18.428478: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,512,6,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,512,6,8]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:38:18.445153: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:382] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2025-11-20 19:38:18.613367: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-11-20 19:38:18.652408: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,512,12,16]{3,2,1,0}, f32[256,512,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:38:18.769878: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,256,24,32]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:38:19.756334: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-20 19:38:19.991715: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-20 19:38:20.295150: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-20 19:38:20.428747: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 15s 32ms/step - accuracy: 0.0981 - loss: 3.1309 - mean_iou_metric: 0.0503
# Epoch 2/500
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3040 - loss: 2.9691 - mean_iou_metric: 0.0992
# I0000 00:00:1763667507.218774 1951109 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.2757 - loss: 2.9489 - mean_iou_metric: 0.0814
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3258 - loss: 3.0071 - mean_iou_metric: 0.0827
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2687 - loss: 2.6337 - mean_iou_metric: 0.0899
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.2652 - loss: 2.4729 - mean_iou_metric: 0.1042
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3014 - loss: 2.1758 - mean_iou_metric: 0.1115
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3580 - loss: 1.8189 - mean_iou_metric: 0.1333
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4039 - loss: 1.6142 - mean_iou_metric: 0.1568
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4782 - loss: 1.4162 - mean_iou_metric: 0.2130
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4613 - loss: 1.2672 - mean_iou_metric: 0.2236
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5961 - loss: 1.0594 - mean_iou_metric: 0.2966
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5672 - loss: 1.1007 - mean_iou_metric: 0.2805
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5183 - loss: 1.1702 - mean_iou_metric: 0.2747
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5342 - loss: 1.0118 - mean_iou_metric: 0.2691
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6317 - loss: 0.8839 - mean_iou_metric: 0.3161
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5745 - loss: 1.0093 - mean_iou_metric: 0.3031
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5225 - loss: 1.0268 - mean_iou_metric: 0.2734
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6030 - loss: 0.8486 - mean_iou_metric: 0.3272
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6016 - loss: 0.9615 - mean_iou_metric: 0.3072
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6476 - loss: 0.8025 - mean_iou_metric: 0.3506
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6271 - loss: 0.8489 - mean_iou_metric: 0.3282
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6524 - loss: 0.7889 - mean_iou_metric: 0.3646
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6446 - loss: 0.8206 - mean_iou_metric: 0.3807
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5715 - loss: 0.8811 - mean_iou_metric: 0.3220
# Epoch 25/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6394 - loss: 0.7864 - mean_iou_metric: 0.3714
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6331 - loss: 0.8684 - mean_iou_metric: 0.3487
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6514 - loss: 0.7695 - mean_iou_metric: 0.3613
# Epoch 28/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6383 - loss: 0.7866 - mean_iou_metric: 0.3589
# Epoch 29/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6604 - loss: 0.7625 - mean_iou_metric: 0.3814
# Epoch 30/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6567 - loss: 0.7717 - mean_iou_metric: 0.3777
# Epoch 31/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6356 - loss: 0.8020 - mean_iou_metric: 0.3576
# Epoch 32/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6619 - loss: 0.7365 - mean_iou_metric: 0.3715
# Epoch 33/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6569 - loss: 0.7824 - mean_iou_metric: 0.3708
# Epoch 34/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6528 - loss: 0.7683 - mean_iou_metric: 0.3640
# Epoch 35/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6617 - loss: 0.7377 - mean_iou_metric: 0.3754
# Epoch 36/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6571 - loss: 0.7739 - mean_iou_metric: 0.3850
# Epoch 37/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6482 - loss: 0.7508 - mean_iou_metric: 0.3893
# Epoch 38/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6512 - loss: 0.7660 - mean_iou_metric: 0.3740
# Epoch 39/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6648 - loss: 0.7631 - mean_iou_metric: 0.3836
# Epoch 40/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6675 - loss: 0.7260 - mean_iou_metric: 0.3860
# Epoch 41/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6544 - loss: 0.7600 - mean_iou_metric: 0.3751
# Epoch 42/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6634 - loss: 0.7567 - mean_iou_metric: 0.3932
# Epoch 43/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6603 - loss: 0.7560 - mean_iou_metric: 0.3811
# Epoch 44/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6607 - loss: 0.7532 - mean_iou_metric: 0.3672
# Epoch 45/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6766 - loss: 0.7202 - mean_iou_metric: 0.4111
# Epoch 46/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6720 - loss: 0.7389 - mean_iou_metric: 0.4072
# Epoch 47/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6501 - loss: 0.7797 - mean_iou_metric: 0.3667
# Epoch 48/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6732 - loss: 0.7168 - mean_iou_metric: 0.3930
# Epoch 49/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6955 - loss: 0.7166 - mean_iou_metric: 0.4264
# Epoch 50/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6096 - loss: 0.7810 - mean_iou_metric: 0.3606
# Epoch 51/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6698 - loss: 0.7533 - mean_iou_metric: 0.3867
# Epoch 52/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6654 - loss: 0.7235 - mean_iou_metric: 0.3822
# Epoch 53/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6989 - loss: 0.6948 - mean_iou_metric: 0.4242
# Epoch 54/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6835 - loss: 0.7500 - mean_iou_metric: 0.4229
# Epoch 55/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7083 - loss: 0.7009 - mean_iou_metric: 0.4475
# Epoch 56/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6846 - loss: 0.6908 - mean_iou_metric: 0.4349
# Epoch 57/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6722 - loss: 0.7036 - mean_iou_metric: 0.3859
# Epoch 58/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6867 - loss: 0.6821 - mean_iou_metric: 0.4167
# Epoch 59/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7508 - loss: 0.6611 - mean_iou_metric: 0.4983
# Epoch 60/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7364 - loss: 0.6554 - mean_iou_metric: 0.4745
# Epoch 61/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7231 - loss: 0.6162 - mean_iou_metric: 0.4499
# Epoch 62/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7483 - loss: 0.6535 - mean_iou_metric: 0.4915
# Epoch 63/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6790 - loss: 0.6917 - mean_iou_metric: 0.4075
# Epoch 64/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6926 - loss: 0.6656 - mean_iou_metric: 0.4227
# Epoch 65/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7133 - loss: 0.6440 - mean_iou_metric: 0.4735
# Epoch 66/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7951 - loss: 0.5590 - mean_iou_metric: 0.5511
# Epoch 67/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8051 - loss: 0.5449 - mean_iou_metric: 0.5631
# Epoch 68/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8190 - loss: 0.4994 - mean_iou_metric: 0.5779
# Epoch 69/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7860 - loss: 0.5995 - mean_iou_metric: 0.5361
# Epoch 70/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7268 - loss: 0.6396 - mean_iou_metric: 0.4713
# Epoch 71/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7650 - loss: 0.6372 - mean_iou_metric: 0.5206
# Epoch 72/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8212 - loss: 0.5058 - mean_iou_metric: 0.5893
# Epoch 73/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7296 - loss: 0.5922 - mean_iou_metric: 0.4656
# Epoch 74/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8015 - loss: 0.5184 - mean_iou_metric: 0.5537
# Epoch 75/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7927 - loss: 0.5249 - mean_iou_metric: 0.5621
# Epoch 76/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8054 - loss: 0.5221 - mean_iou_metric: 0.5752
# Epoch 77/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7506 - loss: 0.5949 - mean_iou_metric: 0.5053
# Epoch 78/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6993 - loss: 0.7330 - mean_iou_metric: 0.4671
# Epoch 79/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7278 - loss: 0.6649 - mean_iou_metric: 0.4417
# Epoch 80/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.7787 - loss: 0.5717 - mean_iou_metric: 0.5353
# Epoch 81/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7603 - loss: 0.5960 - mean_iou_metric: 0.5304
# Epoch 82/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7861 - loss: 0.5706 - mean_iou_metric: 0.5407
# Epoch 83/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8022 - loss: 0.5415 - mean_iou_metric: 0.5613
# Epoch 84/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7970 - loss: 0.5389 - mean_iou_metric: 0.5488
# Epoch 85/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8014 - loss: 0.5228 - mean_iou_metric: 0.5552
# Epoch 86/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7979 - loss: 0.5189 - mean_iou_metric: 0.5506
# Epoch 87/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8156 - loss: 0.4954 - mean_iou_metric: 0.5862
# Epoch 88/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8275 - loss: 0.4560 - mean_iou_metric: 0.5956
# Epoch 89/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8318 - loss: 0.4430 - mean_iou_metric: 0.6035
# Epoch 90/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8315 - loss: 0.4662 - mean_iou_metric: 0.6103
# Epoch 91/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8063 - loss: 0.5290 - mean_iou_metric: 0.5627
# Epoch 92/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8143 - loss: 0.4861 - mean_iou_metric: 0.5944
# Epoch 93/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8270 - loss: 0.4607 - mean_iou_metric: 0.6109
# Epoch 94/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7874 - loss: 0.5392 - mean_iou_metric: 0.5376
# Epoch 95/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7947 - loss: 0.5100 - mean_iou_metric: 0.5554
# Epoch 96/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8217 - loss: 0.4618 - mean_iou_metric: 0.6052
# Epoch 97/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8128 - loss: 0.5018 - mean_iou_metric: 0.5930
# Epoch 98/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8275 - loss: 0.4666 - mean_iou_metric: 0.5859
# Epoch 99/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7598 - loss: 0.6470 - mean_iou_metric: 0.5143
# Epoch 100/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8137 - loss: 0.4836 - mean_iou_metric: 0.5683
# Epoch 101/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8188 - loss: 0.4607 - mean_iou_metric: 0.5499
# Epoch 102/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8365 - loss: 0.4159 - mean_iou_metric: 0.6041
# Epoch 103/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8425 - loss: 0.4125 - mean_iou_metric: 0.6137
# Epoch 104/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8337 - loss: 0.4305 - mean_iou_metric: 0.6067
# Epoch 105/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8566 - loss: 0.3686 - mean_iou_metric: 0.6401
# Epoch 106/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8645 - loss: 0.3579 - mean_iou_metric: 0.6469
# Epoch 107/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8649 - loss: 0.3512 - mean_iou_metric: 0.6447
# Epoch 108/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8603 - loss: 0.3566 - mean_iou_metric: 0.6546
# Epoch 109/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8734 - loss: 0.3393 - mean_iou_metric: 0.6620
# Epoch 110/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8741 - loss: 0.3227 - mean_iou_metric: 0.6749
# Epoch 111/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8759 - loss: 0.3207 - mean_iou_metric: 0.6770
# Epoch 112/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8703 - loss: 0.3271 - mean_iou_metric: 0.6754
# Epoch 113/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8779 - loss: 0.3202 - mean_iou_metric: 0.6803
# Epoch 114/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8786 - loss: 0.3066 - mean_iou_metric: 0.6790
# Epoch 115/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8816 - loss: 0.3015 - mean_iou_metric: 0.6823
# Epoch 116/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8829 - loss: 0.2940 - mean_iou_metric: 0.6879
# Epoch 117/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8860 - loss: 0.2900 - mean_iou_metric: 0.7011
# Epoch 118/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8831 - loss: 0.2910 - mean_iou_metric: 0.6801
# Epoch 119/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8873 - loss: 0.2819 - mean_iou_metric: 0.6953
# Epoch 120/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8885 - loss: 0.2774 - mean_iou_metric: 0.6973
# Epoch 121/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8890 - loss: 0.2738 - mean_iou_metric: 0.7049
# Epoch 122/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8917 - loss: 0.2684 - mean_iou_metric: 0.6952
# Epoch 123/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8922 - loss: 0.2681 - mean_iou_metric: 0.7083
# Epoch 124/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8909 - loss: 0.2711 - mean_iou_metric: 0.7040
# Epoch 125/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8940 - loss: 0.2688 - mean_iou_metric: 0.7167
# Epoch 126/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8965 - loss: 0.2606 - mean_iou_metric: 0.7225
# Epoch 127/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8940 - loss: 0.2616 - mean_iou_metric: 0.7098
# Epoch 128/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8979 - loss: 0.2533 - mean_iou_metric: 0.7061
# Epoch 129/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8984 - loss: 0.2580 - mean_iou_metric: 0.7303
# Epoch 130/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8963 - loss: 0.2683 - mean_iou_metric: 0.7199
# Epoch 131/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6044 - loss: 1.8502 - mean_iou_metric: 0.3852
# Epoch 132/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5804 - loss: 1.1546 - mean_iou_metric: 0.3186
# Epoch 133/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5884 - loss: 1.0510 - mean_iou_metric: 0.3055
# Epoch 134/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6361 - loss: 0.9308 - mean_iou_metric: 0.3236
# Epoch 135/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6608 - loss: 0.7561 - mean_iou_metric: 0.3784
# Epoch 136/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6721 - loss: 0.7372 - mean_iou_metric: 0.4095
# Epoch 137/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6675 - loss: 0.7725 - mean_iou_metric: 0.4034
# Epoch 138/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6822 - loss: 0.7297 - mean_iou_metric: 0.4226
# Epoch 139/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6818 - loss: 0.7303 - mean_iou_metric: 0.4456
# Epoch 140/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7036 - loss: 0.7035 - mean_iou_metric: 0.4464
# Epoch 141/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6922 - loss: 0.6899 - mean_iou_metric: 0.4105
# Epoch 142/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7293 - loss: 0.6688 - mean_iou_metric: 0.4634
# Epoch 143/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7618 - loss: 0.6470 - mean_iou_metric: 0.4877
# Epoch 144/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7119 - loss: 0.6617 - mean_iou_metric: 0.4430
# Epoch 145/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7324 - loss: 0.6828 - mean_iou_metric: 0.4828
# Epoch 146/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7426 - loss: 0.6653 - mean_iou_metric: 0.4957
# Epoch 147/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7470 - loss: 0.6485 - mean_iou_metric: 0.5134
# Epoch 148/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7578 - loss: 0.6362 - mean_iou_metric: 0.5075
# Epoch 149/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7767 - loss: 0.5996 - mean_iou_metric: 0.5177
# Epoch 150/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7846 - loss: 0.5815 - mean_iou_metric: 0.5430
# Epoch 151/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7821 - loss: 0.5723 - mean_iou_metric: 0.5297
# Epoch 152/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7587 - loss: 0.5962 - mean_iou_metric: 0.5170
# Epoch 153/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7710 - loss: 0.6026 - mean_iou_metric: 0.5488
# Epoch 154/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7771 - loss: 0.5878 - mean_iou_metric: 0.5455
# Epoch 155/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7705 - loss: 0.5845 - mean_iou_metric: 0.5226
# Epoch 156/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7982 - loss: 0.5450 - mean_iou_metric: 0.5661
# Epoch 157/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7955 - loss: 0.5415 - mean_iou_metric: 0.5674
# Epoch 158/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7539 - loss: 0.6117 - mean_iou_metric: 0.4991
# Epoch 159/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7834 - loss: 0.5573 - mean_iou_metric: 0.5439
# Epoch 160/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7969 - loss: 0.5386 - mean_iou_metric: 0.5749
# Epoch 161/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8116 - loss: 0.5244 - mean_iou_metric: 0.5927
# Epoch 162/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8112 - loss: 0.5188 - mean_iou_metric: 0.5880
# Epoch 163/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8198 - loss: 0.4950 - mean_iou_metric: 0.5936
# Epoch 164/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8222 - loss: 0.4938 - mean_iou_metric: 0.6070
# Epoch 165/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8251 - loss: 0.4787 - mean_iou_metric: 0.6026
# Epoch 166/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8243 - loss: 0.4917 - mean_iou_metric: 0.6054
# Epoch 167/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8327 - loss: 0.4625 - mean_iou_metric: 0.5906
# Epoch 168/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8213 - loss: 0.4782 - mean_iou_metric: 0.6027
# Epoch 169/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8325 - loss: 0.4558 - mean_iou_metric: 0.6082
# Epoch 170/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7976 - loss: 0.5296 - mean_iou_metric: 0.5720
# Epoch 171/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8133 - loss: 0.5010 - mean_iou_metric: 0.5970
# Epoch 172/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8268 - loss: 0.4871 - mean_iou_metric: 0.6097
# Epoch 173/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8276 - loss: 0.4761 - mean_iou_metric: 0.5923
# Epoch 174/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8318 - loss: 0.4611 - mean_iou_metric: 0.5918
# Epoch 175/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8294 - loss: 0.4710 - mean_iou_metric: 0.5943
# Epoch 176/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8394 - loss: 0.4412 - mean_iou_metric: 0.6308
# Epoch 177/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8259 - loss: 0.4600 - mean_iou_metric: 0.5687
# Epoch 178/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8330 - loss: 0.4631 - mean_iou_metric: 0.5999
# Epoch 179/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8295 - loss: 0.4610 - mean_iou_metric: 0.6082
# Epoch 180/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8333 - loss: 0.4514 - mean_iou_metric: 0.6242
# Epoch 181/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8347 - loss: 0.4533 - mean_iou_metric: 0.5967
# Epoch 182/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8418 - loss: 0.4292 - mean_iou_metric: 0.6262
# Epoch 183/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8371 - loss: 0.4375 - mean_iou_metric: 0.5941
# Epoch 184/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8470 - loss: 0.4088 - mean_iou_metric: 0.6345
# Epoch 185/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8484 - loss: 0.4015 - mean_iou_metric: 0.6343
# Epoch 186/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8487 - loss: 0.3998 - mean_iou_metric: 0.6369
# Epoch 187/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8487 - loss: 0.4056 - mean_iou_metric: 0.6306
# Epoch 188/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8439 - loss: 0.4043 - mean_iou_metric: 0.6258
# Epoch 189/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8442 - loss: 0.4145 - mean_iou_metric: 0.6131
# Epoch 190/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8585 - loss: 0.3807 - mean_iou_metric: 0.6545
# Epoch 191/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8551 - loss: 0.3719 - mean_iou_metric: 0.6448
# Epoch 192/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8486 - loss: 0.3953 - mean_iou_metric: 0.6343
# Epoch 193/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8584 - loss: 0.3624 - mean_iou_metric: 0.6545
# Epoch 194/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8569 - loss: 0.3597 - mean_iou_metric: 0.6498
# Epoch 195/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8638 - loss: 0.3460 - mean_iou_metric: 0.6578
# Epoch 196/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8489 - loss: 0.3784 - mean_iou_metric: 0.6315
# Epoch 197/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8791 - loss: 0.3217 - mean_iou_metric: 0.6938
# Epoch 198/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8787 - loss: 0.3284 - mean_iou_metric: 0.6901
# Epoch 199/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8797 - loss: 0.3168 - mean_iou_metric: 0.6694
# Epoch 200/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8866 - loss: 0.3055 - mean_iou_metric: 0.6967
# Epoch 201/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8854 - loss: 0.3063 - mean_iou_metric: 0.7096
# Epoch 202/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8842 - loss: 0.3044 - mean_iou_metric: 0.7010
# Epoch 203/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8835 - loss: 0.2995 - mean_iou_metric: 0.6886
# Epoch 204/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8908 - loss: 0.2865 - mean_iou_metric: 0.7084
# Epoch 205/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8902 - loss: 0.2884 - mean_iou_metric: 0.7113
# Epoch 206/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8917 - loss: 0.2858 - mean_iou_metric: 0.7137
# Epoch 207/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8935 - loss: 0.2854 - mean_iou_metric: 0.7043
# Epoch 208/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8955 - loss: 0.2763 - mean_iou_metric: 0.7219
# Epoch 209/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8948 - loss: 0.2769 - mean_iou_metric: 0.7220
# Epoch 210/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8971 - loss: 0.2716 - mean_iou_metric: 0.7303
# Epoch 211/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8972 - loss: 0.2691 - mean_iou_metric: 0.7070
# Epoch 212/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8966 - loss: 0.2751 - mean_iou_metric: 0.7213
# Epoch 213/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8948 - loss: 0.2772 - mean_iou_metric: 0.7236
# Epoch 214/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8961 - loss: 0.2713 - mean_iou_metric: 0.7257
# Epoch 215/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9017 - loss: 0.2644 - mean_iou_metric: 0.7313
# Epoch 216/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9030 - loss: 0.2577 - mean_iou_metric: 0.7251
# Epoch 217/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9023 - loss: 0.2573 - mean_iou_metric: 0.7388
# Epoch 218/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9003 - loss: 0.2657 - mean_iou_metric: 0.7221
# Epoch 219/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8899 - loss: 0.2996 - mean_iou_metric: 0.7181
# Epoch 220/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8758 - loss: 0.3103 - mean_iou_metric: 0.7012
# Epoch 221/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8919 - loss: 0.2890 - mean_iou_metric: 0.7187
# Epoch 222/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8963 - loss: 0.2803 - mean_iou_metric: 0.7243
# Epoch 223/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8931 - loss: 0.3046 - mean_iou_metric: 0.7165
# Epoch 224/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8800 - loss: 0.3118 - mean_iou_metric: 0.6976
# Epoch 225/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8851 - loss: 0.2962 - mean_iou_metric: 0.7023
# Epoch 226/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8907 - loss: 0.2963 - mean_iou_metric: 0.7181
# Epoch 227/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8916 - loss: 0.2863 - mean_iou_metric: 0.7110
# Epoch 228/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8895 - loss: 0.2935 - mean_iou_metric: 0.7017
# Epoch 229/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8937 - loss: 0.2789 - mean_iou_metric: 0.7179
# Epoch 230/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8889 - loss: 0.2886 - mean_iou_metric: 0.7076
# Epoch 231/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8942 - loss: 0.2816 - mean_iou_metric: 0.7168
# Epoch 232/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9030 - loss: 0.2576 - mean_iou_metric: 0.7356
# Epoch 233/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9025 - loss: 0.2613 - mean_iou_metric: 0.7428
# Epoch 234/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9021 - loss: 0.2572 - mean_iou_metric: 0.7347
# Epoch 235/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9043 - loss: 0.2554 - mean_iou_metric: 0.7395
# Epoch 236/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9021 - loss: 0.2551 - mean_iou_metric: 0.7324
# Epoch 237/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9056 - loss: 0.2483 - mean_iou_metric: 0.7464
# Epoch 238/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9092 - loss: 0.2424 - mean_iou_metric: 0.7538
# Epoch 239/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9101 - loss: 0.2416 - mean_iou_metric: 0.7517
# Epoch 240/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9108 - loss: 0.2375 - mean_iou_metric: 0.7517
# Epoch 241/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9114 - loss: 0.2320 - mean_iou_metric: 0.7605
# Epoch 242/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9152 - loss: 0.2235 - mean_iou_metric: 0.7634
# Epoch 243/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9172 - loss: 0.2167 - mean_iou_metric: 0.7668
# Epoch 244/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9177 - loss: 0.2123 - mean_iou_metric: 0.7725
# Epoch 245/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9188 - loss: 0.2124 - mean_iou_metric: 0.7762
# Epoch 246/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9177 - loss: 0.2107 - mean_iou_metric: 0.7701
# Epoch 247/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9200 - loss: 0.2040 - mean_iou_metric: 0.7712
# Epoch 248/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9214 - loss: 0.2024 - mean_iou_metric: 0.7718
# Epoch 249/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9215 - loss: 0.2025 - mean_iou_metric: 0.7707
# Epoch 250/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9215 - loss: 0.2065 - mean_iou_metric: 0.7756
# Epoch 251/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9234 - loss: 0.2030 - mean_iou_metric: 0.7918
# Epoch 252/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9210 - loss: 0.2050 - mean_iou_metric: 0.7840
# Epoch 253/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9225 - loss: 0.2038 - mean_iou_metric: 0.7801
# Epoch 254/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9112 - loss: 0.2348 - mean_iou_metric: 0.7431
# Epoch 255/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9191 - loss: 0.2113 - mean_iou_metric: 0.7796
# Epoch 256/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9097 - loss: 0.2345 - mean_iou_metric: 0.7521
# Epoch 257/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9084 - loss: 0.2405 - mean_iou_metric: 0.7501
# Epoch 258/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9088 - loss: 0.2393 - mean_iou_metric: 0.7561
# Epoch 259/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9203 - loss: 0.2098 - mean_iou_metric: 0.7814
# Epoch 260/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9130 - loss: 0.2245 - mean_iou_metric: 0.7580
# Epoch 261/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9212 - loss: 0.2087 - mean_iou_metric: 0.7761
# Epoch 262/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9237 - loss: 0.2047 - mean_iou_metric: 0.7933
# Epoch 263/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9266 - loss: 0.1947 - mean_iou_metric: 0.7919
# Epoch 264/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9273 - loss: 0.1907 - mean_iou_metric: 0.7959
# Epoch 265/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9287 - loss: 0.1902 - mean_iou_metric: 0.7981
# Epoch 266/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9300 - loss: 0.1830 - mean_iou_metric: 0.8017
# Epoch 267/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9343 - loss: 0.1736 - mean_iou_metric: 0.8077
# Epoch 268/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9334 - loss: 0.1735 - mean_iou_metric: 0.8129
# Epoch 269/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9367 - loss: 0.1670 - mean_iou_metric: 0.8235
# Epoch 270/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9363 - loss: 0.1654 - mean_iou_metric: 0.8196
# Epoch 271/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9379 - loss: 0.1650 - mean_iou_metric: 0.8207
# Epoch 272/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9388 - loss: 0.1607 - mean_iou_metric: 0.8221
# Epoch 273/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9378 - loss: 0.1604 - mean_iou_metric: 0.8194
# Epoch 274/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9376 - loss: 0.1625 - mean_iou_metric: 0.8205
# Epoch 275/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9343 - loss: 0.1694 - mean_iou_metric: 0.8200
# Epoch 276/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9320 - loss: 0.1768 - mean_iou_metric: 0.8061
# Epoch 277/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9199 - loss: 0.2091 - mean_iou_metric: 0.7815
# Epoch 278/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9139 - loss: 0.2309 - mean_iou_metric: 0.7680
# Epoch 279/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9130 - loss: 0.2466 - mean_iou_metric: 0.7659
# Epoch 280/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9250 - loss: 0.2025 - mean_iou_metric: 0.7937
# Epoch 281/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9118 - loss: 0.2336 - mean_iou_metric: 0.7725
# Epoch 282/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9185 - loss: 0.2165 - mean_iou_metric: 0.7797
# Epoch 283/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9231 - loss: 0.2141 - mean_iou_metric: 0.7809
# Epoch 284/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9285 - loss: 0.1903 - mean_iou_metric: 0.8072
# Epoch 285/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9306 - loss: 0.1823 - mean_iou_metric: 0.8006
# Epoch 286/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9358 - loss: 0.1695 - mean_iou_metric: 0.8185
# Epoch 287/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9383 - loss: 0.1627 - mean_iou_metric: 0.8192
# Epoch 288/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9378 - loss: 0.1656 - mean_iou_metric: 0.8146
# Epoch 289/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9371 - loss: 0.1660 - mean_iou_metric: 0.8235
# Epoch 290/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9412 - loss: 0.1567 - mean_iou_metric: 0.8335
# Epoch 291/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9417 - loss: 0.1548 - mean_iou_metric: 0.8331
# Epoch 292/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9399 - loss: 0.1592 - mean_iou_metric: 0.8274
# Epoch 293/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9425 - loss: 0.1503 - mean_iou_metric: 0.8314
# Epoch 294/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9432 - loss: 0.1466 - mean_iou_metric: 0.8382
# Epoch 295/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9435 - loss: 0.1467 - mean_iou_metric: 0.8367
# Epoch 296/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9439 - loss: 0.1458 - mean_iou_metric: 0.8419
# Epoch 297/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9468 - loss: 0.1378 - mean_iou_metric: 0.8363
# Epoch 298/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9462 - loss: 0.1396 - mean_iou_metric: 0.8371
# Epoch 299/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9471 - loss: 0.1393 - mean_iou_metric: 0.8505
# Epoch 300/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9476 - loss: 0.1384 - mean_iou_metric: 0.8510
# Epoch 301/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9472 - loss: 0.1359 - mean_iou_metric: 0.8483
# Epoch 302/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9494 - loss: 0.1326 - mean_iou_metric: 0.8503
# Epoch 303/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9495 - loss: 0.1328 - mean_iou_metric: 0.8512
# Epoch 304/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9493 - loss: 0.1323 - mean_iou_metric: 0.8517
# Epoch 305/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9504 - loss: 0.1287 - mean_iou_metric: 0.8477
# Epoch 306/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9488 - loss: 0.1344 - mean_iou_metric: 0.8461
# Epoch 307/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9481 - loss: 0.1329 - mean_iou_metric: 0.8472
# Epoch 308/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9506 - loss: 0.1269 - mean_iou_metric: 0.8480
# Epoch 309/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9506 - loss: 0.1299 - mean_iou_metric: 0.8597
# Epoch 310/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9498 - loss: 0.1303 - mean_iou_metric: 0.8429
# Epoch 311/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9477 - loss: 0.1361 - mean_iou_metric: 0.8460
# Epoch 312/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9473 - loss: 0.1394 - mean_iou_metric: 0.8448
# Epoch 313/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9503 - loss: 0.1287 - mean_iou_metric: 0.8519
# Epoch 314/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9491 - loss: 0.1326 - mean_iou_metric: 0.8536
# Epoch 315/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9467 - loss: 0.1385 - mean_iou_metric: 0.8482
# Epoch 316/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9450 - loss: 0.1470 - mean_iou_metric: 0.8387
# Epoch 317/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9479 - loss: 0.1381 - mean_iou_metric: 0.8438
# Epoch 318/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9454 - loss: 0.1434 - mean_iou_metric: 0.8444
# Epoch 319/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9497 - loss: 0.1319 - mean_iou_metric: 0.8568
# Epoch 320/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9486 - loss: 0.1310 - mean_iou_metric: 0.8391
# Epoch 321/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9485 - loss: 0.1341 - mean_iou_metric: 0.8520
# Epoch 322/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9503 - loss: 0.1291 - mean_iou_metric: 0.8493
# Epoch 323/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9510 - loss: 0.1277 - mean_iou_metric: 0.8481
# Epoch 324/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9508 - loss: 0.1268 - mean_iou_metric: 0.8596
# Epoch 325/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9518 - loss: 0.1253 - mean_iou_metric: 0.8583
# Epoch 326/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9533 - loss: 0.1217 - mean_iou_metric: 0.8666
# Epoch 327/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9543 - loss: 0.1196 - mean_iou_metric: 0.8674
# Epoch 328/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9551 - loss: 0.1149 - mean_iou_metric: 0.8699
# Epoch 329/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9561 - loss: 0.1130 - mean_iou_metric: 0.8688
# Epoch 330/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9558 - loss: 0.1150 - mean_iou_metric: 0.8706
# Epoch 331/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9581 - loss: 0.1090 - mean_iou_metric: 0.8695
# Epoch 332/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9580 - loss: 0.1097 - mean_iou_metric: 0.8700
# Epoch 333/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9561 - loss: 0.1164 - mean_iou_metric: 0.8677
# Epoch 334/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9572 - loss: 0.1116 - mean_iou_metric: 0.8706
# Epoch 335/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9554 - loss: 0.1149 - mean_iou_metric: 0.8664
# Epoch 336/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9555 - loss: 0.1142 - mean_iou_metric: 0.8706
# Epoch 337/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9577 - loss: 0.1100 - mean_iou_metric: 0.8711
# Epoch 338/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9566 - loss: 0.1140 - mean_iou_metric: 0.8710
# Epoch 339/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9591 - loss: 0.1067 - mean_iou_metric: 0.8795
# Epoch 340/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9606 - loss: 0.1036 - mean_iou_metric: 0.8840
# Epoch 341/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9591 - loss: 0.1063 - mean_iou_metric: 0.8819
# Epoch 342/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9595 - loss: 0.1051 - mean_iou_metric: 0.8729
# Epoch 343/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9604 - loss: 0.1046 - mean_iou_metric: 0.8802
# Epoch 344/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9614 - loss: 0.1006 - mean_iou_metric: 0.8869
# Epoch 345/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9620 - loss: 0.0992 - mean_iou_metric: 0.8894
# Epoch 346/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9616 - loss: 0.0982 - mean_iou_metric: 0.8849
# Epoch 347/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9627 - loss: 0.0978 - mean_iou_metric: 0.8909
# Epoch 348/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9609 - loss: 0.1004 - mean_iou_metric: 0.8811
# Epoch 349/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9615 - loss: 0.0999 - mean_iou_metric: 0.8781
# Epoch 350/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9596 - loss: 0.1050 - mean_iou_metric: 0.8817
# Epoch 351/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9606 - loss: 0.0999 - mean_iou_metric: 0.8812
# Epoch 352/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9596 - loss: 0.1025 - mean_iou_metric: 0.8785
# Epoch 353/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9592 - loss: 0.1051 - mean_iou_metric: 0.8815
# Epoch 354/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9601 - loss: 0.1040 - mean_iou_metric: 0.8868
# Epoch 355/500
# ...
# Epoch 359/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9654 - loss: 0.0897 - mean_iou_metric: 0.8981
# Epoch 360/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9647 - loss: 0.0897 - mean_iou_metric: 0.8942
# Epoch 361/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9629 - loss: 0.0939 - mean_iou_metric: 0.8825
# Epoch 362/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9655 - loss: 0.0875 - mean_iou_metric: 0.8967
# Epoch 363/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9640 - loss: 0.0903 - mean_iou_metric: 0.8929
# Epoch 364/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9634 - loss: 0.0932 - mean_iou_metric: 0.8854
# Epoch 365/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9649 - loss: 0.0897 - mean_iou_metric: 0.8894
# Epoch 366/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9638 - loss: 0.0918 - mean_iou_metric: 0.8958
# Epoch 367/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9650 - loss: 0.0889 - mean_iou_metric: 0.8949
# Epoch 368/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9667 - loss: 0.0858 - mean_iou_metric: 0.9018
# Epoch 369/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9657 - loss: 0.0871 - mean_iou_metric: 0.9005
# Epoch 370/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9649 - loss: 0.0875 - mean_iou_metric: 0.8912
# Epoch 371/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9670 - loss: 0.0845 - mean_iou_metric: 0.8994
# Epoch 372/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9669 - loss: 0.0839 - mean_iou_metric: 0.9040
# Epoch 373/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9651 - loss: 0.0862 - mean_iou_metric: 0.8930
# Epoch 374/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9665 - loss: 0.0852 - mean_iou_metric: 0.8946
# Epoch 375/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9643 - loss: 0.0901 - mean_iou_metric: 0.8909
# Epoch 376/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9640 - loss: 0.0921 - mean_iou_metric: 0.8896
# Epoch 377/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9622 - loss: 0.0934 - mean_iou_metric: 0.8894
# Epoch 378/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9613 - loss: 0.0981 - mean_iou_metric: 0.8889
# Epoch 379/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9642 - loss: 0.0903 - mean_iou_metric: 0.8948
# Epoch 380/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9653 - loss: 0.0880 - mean_iou_metric: 0.8972
# Epoch 381/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9677 - loss: 0.0835 - mean_iou_metric: 0.9029
# Epoch 382/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9668 - loss: 0.0843 - mean_iou_metric: 0.9044
# Epoch 383/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9664 - loss: 0.0838 - mean_iou_metric: 0.8893
# Epoch 384/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9688 - loss: 0.0797 - mean_iou_metric: 0.9057
# Epoch 385/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9688 - loss: 0.0780 - mean_iou_metric: 0.9048
# Epoch 386/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9672 - loss: 0.0835 - mean_iou_metric: 0.8990
# Epoch 387/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9686 - loss: 0.0796 - mean_iou_metric: 0.9042
# Epoch 388/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9694 - loss: 0.0780 - mean_iou_metric: 0.9072
# Epoch 389/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9700 - loss: 0.0767 - mean_iou_metric: 0.9100
# Epoch 390/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9710 - loss: 0.0744 - mean_iou_metric: 0.9144
# Epoch 391/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9722 - loss: 0.0719 - mean_iou_metric: 0.9177
# Epoch 392/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9717 - loss: 0.0717 - mean_iou_metric: 0.9156
# Epoch 393/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9722 - loss: 0.0696 - mean_iou_metric: 0.9173
# Epoch 394/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9738 - loss: 0.0683 - mean_iou_metric: 0.9226
# Epoch 395/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9726 - loss: 0.0688 - mean_iou_metric: 0.9123
# Epoch 396/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9725 - loss: 0.0696 - mean_iou_metric: 0.9109
# Epoch 397/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9726 - loss: 0.0688 - mean_iou_metric: 0.9197
# Epoch 398/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9735 - loss: 0.0676 - mean_iou_metric: 0.9214
# Epoch 399/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9733 - loss: 0.0671 - mean_iou_metric: 0.9202
# Epoch 400/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9717 - loss: 0.0713 - mean_iou_metric: 0.9118
# Epoch 401/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9730 - loss: 0.0686 - mean_iou_metric: 0.9189
# Epoch 402/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9718 - loss: 0.0692 - mean_iou_metric: 0.9139
# Epoch 403/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9729 - loss: 0.0701 - mean_iou_metric: 0.9140
# Epoch 404/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9735 - loss: 0.0665 - mean_iou_metric: 0.9208
# Epoch 405/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9722 - loss: 0.0701 - mean_iou_metric: 0.9126
# Epoch 406/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9736 - loss: 0.0672 - mean_iou_metric: 0.9191
# Epoch 407/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9746 - loss: 0.0643 - mean_iou_metric: 0.9245
# Epoch 408/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9766 - loss: 0.0599 - mean_iou_metric: 0.9292
# Epoch 409/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9776 - loss: 0.0585 - mean_iou_metric: 0.9303
# Epoch 410/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9765 - loss: 0.0592 - mean_iou_metric: 0.9294
# Epoch 411/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9773 - loss: 0.0574 - mean_iou_metric: 0.9317
# Epoch 412/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9782 - loss: 0.0562 - mean_iou_metric: 0.9343
# Epoch 413/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9786 - loss: 0.0556 - mean_iou_metric: 0.9311
# Epoch 414/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9784 - loss: 0.0551 - mean_iou_metric: 0.9353
# Epoch 415/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9796 - loss: 0.0530 - mean_iou_metric: 0.9388
# Epoch 416/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9781 - loss: 0.0564 - mean_iou_metric: 0.9314
# Epoch 417/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9760 - loss: 0.0586 - mean_iou_metric: 0.9238
# Epoch 418/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9728 - loss: 0.0691 - mean_iou_metric: 0.9137
# Epoch 419/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9704 - loss: 0.0765 - mean_iou_metric: 0.9128
# Epoch 420/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9718 - loss: 0.0714 - mean_iou_metric: 0.9163
# Epoch 421/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9709 - loss: 0.0744 - mean_iou_metric: 0.9121
# Epoch 422/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9719 - loss: 0.0702 - mean_iou_metric: 0.9180
# Epoch 423/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9716 - loss: 0.0737 - mean_iou_metric: 0.9143
# Epoch 424/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9760 - loss: 0.0622 - mean_iou_metric: 0.9290
# Epoch 425/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9755 - loss: 0.0629 - mean_iou_metric: 0.9266
# Epoch 426/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9780 - loss: 0.0577 - mean_iou_metric: 0.9347
# Epoch 427/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9784 - loss: 0.0554 - mean_iou_metric: 0.9353
# Epoch 428/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9787 - loss: 0.0551 - mean_iou_metric: 0.9370
# Epoch 429/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9779 - loss: 0.0561 - mean_iou_metric: 0.9336
# Epoch 430/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9794 - loss: 0.0524 - mean_iou_metric: 0.9384
# Epoch 431/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9797 - loss: 0.0530 - mean_iou_metric: 0.9394
# Epoch 432/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9810 - loss: 0.0499 - mean_iou_metric: 0.9394
# Epoch 433/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9807 - loss: 0.0498 - mean_iou_metric: 0.9397
# Epoch 434/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9793 - loss: 0.0525 - mean_iou_metric: 0.9361
# Epoch 435/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9815 - loss: 0.0488 - mean_iou_metric: 0.9409
# Epoch 436/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9814 - loss: 0.0481 - mean_iou_metric: 0.9443
# Epoch 437/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9814 - loss: 0.0473 - mean_iou_metric: 0.9395
# Epoch 438/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9817 - loss: 0.0466 - mean_iou_metric: 0.9404
# Epoch 439/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9827 - loss: 0.0457 - mean_iou_metric: 0.9429
# Epoch 440/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9836 - loss: 0.0434 - mean_iou_metric: 0.9498
# Epoch 441/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9832 - loss: 0.0435 - mean_iou_metric: 0.9457
# Epoch 442/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9829 - loss: 0.0442 - mean_iou_metric: 0.9420
# Epoch 443/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9833 - loss: 0.0432 - mean_iou_metric: 0.9497
# Epoch 444/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9836 - loss: 0.0428 - mean_iou_metric: 0.9480
# Epoch 445/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9819 - loss: 0.0462 - mean_iou_metric: 0.9437
# Epoch 446/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9790 - loss: 0.0529 - mean_iou_metric: 0.9334
# Epoch 447/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9740 - loss: 0.0653 - mean_iou_metric: 0.9223
# Epoch 448/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9724 - loss: 0.0709 - mean_iou_metric: 0.9181
# Epoch 449/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9738 - loss: 0.0653 - mean_iou_metric: 0.9224
# Epoch 450/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9693 - loss: 0.0851 - mean_iou_metric: 0.9158
# Epoch 451/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9742 - loss: 0.0679 - mean_iou_metric: 0.9247
# Epoch 452/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9741 - loss: 0.0652 - mean_iou_metric: 0.9222
# Epoch 453/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9756 - loss: 0.0622 - mean_iou_metric: 0.9260
# Epoch 454/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9785 - loss: 0.0567 - mean_iou_metric: 0.9356
# Epoch 455/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9787 - loss: 0.0555 - mean_iou_metric: 0.9315
# Epoch 456/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9784 - loss: 0.0547 - mean_iou_metric: 0.9322
# Epoch 457/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9778 - loss: 0.0568 - mean_iou_metric: 0.9336
# Epoch 458/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9792 - loss: 0.0530 - mean_iou_metric: 0.9380
# Epoch 459/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9806 - loss: 0.0514 - mean_iou_metric: 0.9418
# Epoch 460/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9825 - loss: 0.0456 - mean_iou_metric: 0.9485
# Epoch 461/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9844 - loss: 0.0425 - mean_iou_metric: 0.9499
# Epoch 462/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9824 - loss: 0.0453 - mean_iou_metric: 0.9473
# Epoch 463/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9843 - loss: 0.0415 - mean_iou_metric: 0.9503
# Epoch 464/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9850 - loss: 0.0390 - mean_iou_metric: 0.9542
# Epoch 465/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9849 - loss: 0.0397 - mean_iou_metric: 0.9539
# Epoch 466/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9851 - loss: 0.0391 - mean_iou_metric: 0.9532
# Epoch 467/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9870 - loss: 0.0361 - mean_iou_metric: 0.9597
# Epoch 468/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9865 - loss: 0.0359 - mean_iou_metric: 0.9547
# Epoch 469/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9883 - loss: 0.0322 - mean_iou_metric: 0.9621
# Epoch 470/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9883 - loss: 0.0314 - mean_iou_metric: 0.9611
# Epoch 471/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9878 - loss: 0.0313 - mean_iou_metric: 0.9601
# Epoch 472/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9878 - loss: 0.0325 - mean_iou_metric: 0.9625
# Epoch 473/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9881 - loss: 0.0312 - mean_iou_metric: 0.9636
# Epoch 474/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9896 - loss: 0.0290 - mean_iou_metric: 0.9677
# Epoch 475/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9906 - loss: 0.0266 - mean_iou_metric: 0.9680
# Epoch 476/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9894 - loss: 0.0283 - mean_iou_metric: 0.9668
# Epoch 477/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9896 - loss: 0.0279 - mean_iou_metric: 0.9682
# Epoch 478/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9897 - loss: 0.0264 - mean_iou_metric: 0.9686
# Epoch 479/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9904 - loss: 0.0264 - mean_iou_metric: 0.9702
# Epoch 480/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9911 - loss: 0.0248 - mean_iou_metric: 0.9695
# Epoch 481/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9905 - loss: 0.0259 - mean_iou_metric: 0.9679
# Epoch 482/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9905 - loss: 0.0255 - mean_iou_metric: 0.9679
# Epoch 483/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9902 - loss: 0.0256 - mean_iou_metric: 0.9676
# Epoch 484/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9897 - loss: 0.0264 - mean_iou_metric: 0.9653
# Epoch 485/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9899 - loss: 0.0275 - mean_iou_metric: 0.9685
# Epoch 486/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9896 - loss: 0.0279 - mean_iou_metric: 0.9659
# Epoch 487/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9880 - loss: 0.0309 - mean_iou_metric: 0.9625
# Epoch 488/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9892 - loss: 0.0284 - mean_iou_metric: 0.9637
# Epoch 489/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9900 - loss: 0.0261 - mean_iou_metric: 0.9669
# Epoch 490/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9906 - loss: 0.0252 - mean_iou_metric: 0.9702
# Epoch 491/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9903 - loss: 0.0257 - mean_iou_metric: 0.9699
# Epoch 492/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9902 - loss: 0.0265 - mean_iou_metric: 0.9674
# Epoch 493/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9901 - loss: 0.0263 - mean_iou_metric: 0.9693
# Epoch 494/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9894 - loss: 0.0277 - mean_iou_metric: 0.9657
# Epoch 495/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9897 - loss: 0.0278 - mean_iou_metric: 0.9682
# Epoch 496/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9888 - loss: 0.0284 - mean_iou_metric: 0.9655
# Epoch 497/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9886 - loss: 0.0306 - mean_iou_metric: 0.9622
# Epoch 498/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9836 - loss: 0.0442 - mean_iou_metric: 0.9521
# Epoch 499/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9881 - loss: 0.0306 - mean_iou_metric: 0.9629
# Epoch 500/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9831 - loss: 0.0446 - mean_iou_metric: 0.9458

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
plt.plot(model_history.history["accuracy"])

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

# %%
def create_mask(pred_mask):
    pred_mask = tf.argmax(pred_mask, axis=-1)
    pred_mask = pred_mask[..., tf.newaxis]
    return pred_mask[0]

# %%
def show_predictions(dataset=None, num=1):
    """
    Displays the first image of each of the num batches
    """
    if dataset:
        for image, mask in dataset.take(num):
            pred_mask = unet.predict(image)
            display([image[0], mask[0], create_mask(pred_mask)])
    else:
        display([sample_image, sample_mask,
             create_mask(unet.predict(sample_image[tf.newaxis, ...]))])

# %%
print(EPOCHS)
# Out:
# 500

# %%
print("----- training_dataset results---------")
show_predictions(train_dataset, 6)
print("----- validation_dataset results---------")
show_predictions(validation_dataset, 6)
# Out:
# ----- training_dataset results---------
# 2025-11-20 19:39:16.336123: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,64,24,32]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:16.380840: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,128,24,32]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:16.431913: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,128,12,16]{3,2,1,0}, f32[256,128,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:16.477744: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,256,12,16]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:16.528719: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,512,6,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,256,6,8]{3,2,1,0}, f32[512,256,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:16.592330: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,512,6,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,512,6,8]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:16.753073: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,512,12,16]{3,2,1,0}, f32[256,512,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:16.823992: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,256,24,32]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# ----- validation_dataset results---------
# 2025-11-20 19:39:18.901688: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,64,24,32]{3,2,1,0}, f32[128,64,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:18.946503: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,128,24,32]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:18.993795: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,128,12,16]{3,2,1,0}, f32[256,128,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:19.040031: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,256,12,16]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:19.086852: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,512,6,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,256,6,8]{3,2,1,0}, f32[512,256,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:19.148253: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,512,6,8]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,512,6,8]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:19.224581: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-11-20 19:39:19.264267: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,256,12,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,512,12,16]{3,2,1,0}, f32[256,512,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-11-20 19:39:19.366720: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,24,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,256,24,32]{3,2,1,0}, f32[128,256,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 2025-11-20 19:39:20.320835: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# model evaluation
print("Unet Model Evaluation: ")
unet.evaluate(validation_dataset)
# Out:
# Unet Model Evaluation:
# 2025-11-20 19:39:20.828815: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9611 - loss: 0.1017 - mean_iou_metric: 0.8528
# [0.1017330139875412, 0.9611002802848816, 0.8528411388397217]
